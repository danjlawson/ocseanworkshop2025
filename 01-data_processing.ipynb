# %% [markdown]
# # **Processing the Linguistic data**
# This uses the "OCSEAN_language_collection_overview_June_25.xlsx" data, CleanedFiles and CleanedFiles-v1.1 folders.
#
# This is the first step in the processing pipeline to go from assorted wordlists to a consistent unified dataset.
#
# This uses:
# * `Metadata/OCSEAN_language_collection_overview_June_25.xlsx` metadata, which is an update from the `April` version provided,
# * `CleanedFiles`, which were provided to us at the beginning of the workshop,
# * `CleanedFiles-v1.1` which have been manually curated by the Bristol Linguistic Data Science team and are updates to the CleanedFiles folder,
# * `OCSEAN_rareconcepts_matching_correction` which is a manual correction of the automatically generated `OCSEAN_rareconcepts_matching.xlsx`, which defines mappings between concepts to make them consistent.

# %% [markdown]
# # Install and import modules

# %%
# Uncomment any in case a module is not yet installed
# !pip install cartopy==0.24.1
# !pip install Counter==1.0.0
# !pip install datetime==5.5
# !pip install eng-to-ipa==0.0.2
# !pip install geopandas==1.1.0
# !pip install lingpy==2.6.13
# !pip install matplotlib==3.9.2
# !pip install numpy==1.26.4
# !pip install pathlib==1.0.1
# !pip install pandas==2.2.2
# !pip install seaborn==0.13.2
# !pip install scikit-learn==1.5.1
# !pip install shapely==2.1.1
# !pip install tabulate==0.9.0
# !pip install thefuzz==0.22.1
# Out:
# Requirement already satisfied: cartopy==0.24.1 in c:\users\dmsfr\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (3.9.2)
# Requirement already satisfied: shapely>=1.8 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (2.1.1)
# Requirement already satisfied: packaging>=21 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (24.1)
# Requirement already satisfied: pyshp>=2.3 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from cartopy==0.24.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy==0.24.1) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\dmsfr\anaconda3\lib\site-packages (from pyproj>=3.3.1->cartopy==0.24.1) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy==0.24.1) (1.16.0)
# Requirement already satisfied: Counter==1.0.0 in c:\users\dmsfr\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: datetime==5.5 in c:\users\dmsfr\anaconda3\lib\site-packages (5.5)
# Requirement already satisfied: zope.interface in c:\users\dmsfr\anaconda3\lib\site-packages (from datetime==5.5) (5.4.0)
# Requirement already satisfied: pytz in c:\users\dmsfr\anaconda3\lib\site-packages (from datetime==5.5) (2024.1)
# Requirement already satisfied: setuptools in c:\users\dmsfr\anaconda3\lib\site-packages (from zope.interface->datetime==5.5) (75.1.0)
# Requirement already satisfied: eng-to-ipa==0.0.2 in c:\users\dmsfr\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: geopandas==1.1.0 in c:\users\dmsfr\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (0.11.0)
# Requirement already satisfied: packaging in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (24.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from geopandas==1.1.0) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas==1.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas==1.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas==1.1.0) (2023.3)
# Requirement already satisfied: certifi in c:\users\dmsfr\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas==1.1.0) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas==1.1.0) (1.16.0)
# Requirement already satisfied: lingpy==2.6.13 in c:\users\dmsfr\anaconda3\lib\site-packages (2.6.13)
# Requirement already satisfied: numpy in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (1.26.4)
# Requirement already satisfied: appdirs in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (1.4.4)
# Requirement already satisfied: networkx>=2.3 in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (3.3)
# Requirement already satisfied: tqdm in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (4.66.5)
# Requirement already satisfied: csvw>=1.5.6 in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (3.5.1)
# Requirement already satisfied: clldutils>=2.8.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (3.24.2)
# Requirement already satisfied: pycldf>=1.7.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (1.42.0)
# Requirement already satisfied: lxml in c:\users\dmsfr\anaconda3\lib\site-packages (from lingpy==2.6.13) (5.2.1)
# Requirement already satisfied: python-dateutil in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (2.9.0.post0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (0.9.0)
# Requirement already satisfied: colorlog in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (6.9.0)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (23.1.0)
# Requirement already satisfied: bibtexparser>=2.0.0b4 in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (2.0.0b8)
# Requirement already satisfied: pylatexenc in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (2.10)
# Requirement already satisfied: markdown in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (3.4.1)
# Requirement already satisfied: markupsafe in c:\users\dmsfr\anaconda3\lib\site-packages (from clldutils>=2.8.0->lingpy==2.6.13) (2.1.3)
# Requirement already satisfied: isodate in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (0.7.2)
# Requirement already satisfied: rfc3986<2 in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (4.1.1)
# Requirement already satisfied: babel in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (2.11.0)
# Requirement already satisfied: requests in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (2.32.3)
# Requirement already satisfied: language-tags in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (1.2.0)
# Requirement already satisfied: rdflib in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (7.1.4)
# Requirement already satisfied: colorama in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (0.4.6)
# Requirement already satisfied: jsonschema in c:\users\dmsfr\anaconda3\lib\site-packages (from csvw>=1.5.6->lingpy==2.6.13) (4.23.0)
# Requirement already satisfied: setuptools in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (75.1.0)
# Requirement already satisfied: pybtex in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (0.24.0)
# Requirement already satisfied: newick in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (1.10.0)
# Requirement already satisfied: commonnexus>=1.2.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (1.9.2)
# Requirement already satisfied: python-frontmatter in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (1.1.0)
# Requirement already satisfied: termcolor in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (3.1.0)
# Requirement already satisfied: PyYAML in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (6.0.1)
# Requirement already satisfied: jmespath in c:\users\dmsfr\anaconda3\lib\site-packages (from pycldf>=1.7.0->lingpy==2.6.13) (1.0.1)
# Requirement already satisfied: pytz>=2015.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from babel->csvw>=1.5.6->lingpy==2.6.13) (2024.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dmsfr\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->lingpy==2.6.13) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dmsfr\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->lingpy==2.6.13) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->lingpy==2.6.13) (0.10.6)
# Requirement already satisfied: latexcodec>=1.0.4 in c:\users\dmsfr\anaconda3\lib\site-packages (from pybtex->pycldf>=1.7.0->lingpy==2.6.13) (3.0.0)
# Requirement already satisfied: six in c:\users\dmsfr\anaconda3\lib\site-packages (from pybtex->pycldf>=1.7.0->lingpy==2.6.13) (1.16.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from rdflib->csvw>=1.5.6->lingpy==2.6.13) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dmsfr\anaconda3\lib\site-packages (from requests->csvw>=1.5.6->lingpy==2.6.13) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from requests->csvw>=1.5.6->lingpy==2.6.13) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from requests->csvw>=1.5.6->lingpy==2.6.13) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dmsfr\anaconda3\lib\site-packages (from requests->csvw>=1.5.6->lingpy==2.6.13) (2025.4.26)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\dmsfr\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.16.0)
# Requirement already satisfied: numpy==1.26.4 in c:\users\dmsfr\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pathlib==1.0.1 in c:\users\dmsfr\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\dmsfr\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas==2.2.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\dmsfr\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dmsfr\anaconda3\lib\site-packages (from seaborn==0.13.2) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dmsfr\anaconda3\lib\site-packages (from seaborn==0.13.2) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dmsfr\anaconda3\lib\site-packages (from seaborn==0.13.2) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dmsfr\anaconda3\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.16.0)
# Requirement already satisfied: scikit-learn==1.5.1 in c:\users\dmsfr\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dmsfr\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (3.5.0)
# Requirement already satisfied: shapely==2.1.1 in c:\users\dmsfr\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\dmsfr\anaconda3\lib\site-packages (from shapely==2.1.1) (1.26.4)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\dmsfr\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: thefuzz==0.22.1 in c:\users\dmsfr\anaconda3\lib\site-packages (0.22.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\users\dmsfr\anaconda3\lib\site-packages (from thefuzz==0.22.1) (3.13.0)

# %%
import os 
import pandas as pd 
import numpy as np
import re
import math
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import cartopy.crs as ccrs
import cartopy.feature as cfeature

from thefuzz import process
from lingpy import * # We're just importing everything from lingpy for simplicity
from lingpy import Wordlist, LexStat, Alignments, Tree, SCA # This is just to track that we used lingly module for these functions
from lingpy.sequence.sound_classes import ipa2tokens
from lingpy.compare.sanity import average_coverage, mutual_coverage_check, synonymy
from lingpy.convert.cldf import to_cldf
from datetime import datetime
from itertools import combinations
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from tabulate import tabulate
from shapely.geometry import Point
from collections import Counter, defaultdict
from pathlib import Path
# Out:
# /Users/madjl/uv/ocsean_venv/lib/python3.12/site-packages/pybtex/plugin/__init__.py:26: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# Setting new directory
#os.chdir('/Users/dmsfr/OCSEAN @ Bristol/Process Linguist Data') 

# Folder name in current directory where all files (Excel, images, etc. will be saved)
results_folder_name = 'Pipeline results'

# Check if the folder exists, if not, create it
if not os.path.exists(results_folder_name):
    os.makedirs(results_folder_name)
    print(f"Folder '{results_folder_name}' created successfully.")
else:
    print(f"Folder '{results_folder_name}' already exists. Using existing folder.")
# Out:
# Folder 'Pipeline results' created successfully.

# %% [markdown]
# # Load the Collection of Languages Data

# %%
collection_sheet = pd.read_excel(os.path.join("Metadata","OCSEAN_language_collection_overview_June_25.xlsx"))
#collection_sheet # View the data # Uncomment to show the data

# %% [markdown]
# # Add 'latitude' and 'longitude'

# %%
def parse_location(text):
    """Parse location coordinates from decimal degrees or DMS format."""
    # Handle NaN or non-string values
    if pd.isna(text) or not isinstance(text, str):
        return None, None
    
    # Check for decimal degrees format first
    decimal_match = re.match(r'\s*(-?\d+(?:\.\d+)?)\s*,\s*(-?\d+(?:\.\d+)?)\s*', text)
    if decimal_match:
        return float(decimal_match.group(1)), float(decimal_match.group(2))
    
    # Match DMS format and convert inline
    dms_regex = re.findall(r"(\d+)[°](\d+)'(\d+(?:\.\d+)?)\"?([NSEW])", text)
    if len(dms_regex) == 2:
        lat_data, lon_data = dms_regex
        
        # Convert DMS to decimal degrees inline
        lat = float(lat_data[0]) + float(lat_data[1])/60 + float(lat_data[2])/3600
        if lat_data[3] == 'S':
            lat *= -1
            
        lon = float(lon_data[0]) + float(lon_data[1])/60 + float(lon_data[2])/3600
        if lon_data[3] == 'W':
            lon *= -1
            
        return lat, lon
    
    return None, None  # Fallback if format doesn't match

# %%
# Apply parsing
collection_sheet[['latitude', 'longitude']] = collection_sheet['Google Map Coordinate'].apply(lambda x: pd.Series(parse_location(x)))

# %% [markdown]
# # Add a column 'Has_QC_File' and 'File_Source'
# which determines if a language has been QC'd and the file folder where it is saved

# %%
# Initialize all tracking variables
languages_v11 = set()
languages_original = set()
collection = {}  # Stores DataFrames loaded from Excel files
colnames = {}    # Stores column names from each DataFrame
processed_languages = set()  # Track already processed languages

# Add columns to collection_sheet
collection_sheet["Has_QC_File"] = False
collection_sheet["File_Source"] = ""  # Track which folder the file came from

def get_file_path(file_name):
    """Helper function to determine file path and source"""
    if pd.isna(file_name) or file_name == "":
        return None, None
    
    # Check CleanedFiles-v1.1 first
    edited_path = os.path.join("CleanedFiles-v1.1", f"edited-{file_name}")
    if os.path.isfile(edited_path):
        return edited_path, "CleanedFiles-v1.1"
    
    # Check original CleanedFiles folder
    original_path = os.path.join("CleanedFiles", file_name)
    if os.path.isfile(original_path):
        return original_path, "CleanedFiles"
    
    return None, None

# Single loop to process all files
for id in collection_sheet.index:
    file_name = collection_sheet.at[id, "QC_FileName"]
    language = collection_sheet.at[id, "Language_BasedOnMasterSheet"]
    
    # Get file path and source
    file_path, source = get_file_path(file_name)
    
    if file_path is None:
        continue  # File doesn't exist, skip
    
    # Update collection_sheet with file existence info
    collection_sheet.at[id, "Has_QC_File"] = True
    collection_sheet.at[id, "File_Source"] = source
    
    # Track languages by source
    if not pd.isna(language):
        if source == "CleanedFiles-v1.1":
            languages_v11.add(language)
        else:  # source == "CleanedFiles"
            languages_original.add(language)
        
        # Load file only if language hasn't been processed yet
        if language not in processed_languages:
            try:
                collection[language] = pd.read_excel(file_path)
                colnames[language] = list(collection[language].columns.values)
                processed_languages.add(language)
                #print(f"Successfully loaded {language} from {source}")
            except Exception as e:
                print(f"Error reading {file_path}: {str(e)}")

# Create filtered dataframes
clean_sheet  = collection_sheet[collection_sheet["Has_QC_File"] == True]
broken_sheet = collection_sheet[collection_sheet["Has_QC_File"] == False]

# Generate language reports
languages_v11_list = sorted(list(languages_v11))
languages_original_list = sorted(list(languages_original))
all_languages = set(collection_sheet["Language_BasedOnMasterSheet"].dropna().unique())
languages_no_files = sorted(list(all_languages - languages_v11 - languages_original))

# Print results
print(f"Languages loaded from 'CleanedFiles-v1.1' (n = {len(languages_v11_list)}):")
print(", ".join(languages_v11_list) if languages_v11_list else "None")

print(f"\nLanguages loaded from 'CleanedFiles' (n = {len(languages_original_list)}):")
print(", ".join(languages_original_list) if languages_original_list else "None")

print(f"\nLanguages with no files loaded from either folder (n = {len(languages_no_files)}):")
print(", ".join(languages_no_files) if languages_no_files else "All languages have files loaded")

print(f"\nSummary:")
print(f"- Total files loaded: {len(collection)}")
print(f"- Files from CleanedFiles-v1.1: {sum(1 for lang in processed_languages if lang in languages_v11)}")
print(f"- Files from CleanedFiles: {sum(1 for lang in processed_languages if lang in languages_original and lang not in languages_v11)}")
print(f"- Rows with QC files: {len(clean_sheet)}")
print(f"- Rows without QC files: {len(broken_sheet)}")
# Out:
# Languages loaded from 'CleanedFiles-v1.1' (n = 61):
# Abui Bunggeta, Abui Kilakawada, Abui Mobyetang, Adang, Agta, Agusan Manobo, Agutaynen, Akeanon, Alurung, Arta, Ata, Ati, Balangao, Bali Aga, Batak, Boholano, Bolinao, Bontoc, Bulus, Cuyunon, Dela, Enggano, Hanunuo, Hiligaynon_20220813, Ibaloy/ Ibaloi, Ibanag, Ilognon (Hiligaynon), Inabaknon, Ivatan Isabtangan, Ivatan Itbayaten / Ivatan_Ichbayatan, Kamayo, Kankana-ey, Kapampangan, Kelon, Kinaray-a, Klon, Kolibogan, Kusa, Loloan Malay, Manea, Manobo Tasaday, Mauta, Meranao, Minamanwa, Obo Manobo, Pangasinan, Reta Ternate, Sabu Raijua, Sangil, Sinama Banguingui, Sinama Sitangkai, Sinama Tabawan, Sinurigaonon, Tagbanua Central, Talaandig (Binukid), Tausug, Tboli, Tuwali, Umbu-Ungu, Waray, Yakan
#
# Languages loaded from 'CleanedFiles' (n = 19):
# Abui Pelman, Ba'a, Balinese, Bicolano, Buhid, Chabacano Caviteño , Gaddang, Hattang Kaye, Hiligaynon_20240802, Ilokano, Kalinga, Kupang Malay, Mawes Wares, Mawesdai, Molbog, Palawano, Sabu Seba, Tagakaulo, Uab Meto
#
# Languages with no files loaded from either folder (n = 36):
# Abui Takalelang, Alorung/Alorese Alor Kecil, Amanuban, Bagobo Tagabawa, Blaan Sarangani, Blagar Pantar Timur, Butuanon, Casiguranin, Cebuano, Dumagat San Luis Aurora, Higaonon, Ilongot, Iranun, Iraya, Ivatan, Kagan, Kamang Bukapiting, Mentawai Buttui, Mentawai Muntei, Rote, Dengka, Rote, Talae, Rote, Tii, Sabu Seba Ethnobotany, Sabu, Liae, Sambal, Savu, Sinama Davao, Subanen, Sumba Wejewa, Sumba, Anakalang, Sumba, Loli, Tagbanwa Tandulanen, Termanu, Tetun, Atambua, Umajamnon, Wersing Pantai Selatan
#
# Summary:
# - Total files loaded: 80
# - Files from CleanedFiles-v1.1: 61
# - Files from CleanedFiles: 19
# - Rows with QC files: 80
# - Rows without QC files: 42

# %% [markdown]
# You will notice discrepancies in the number of files loaded versus the number of languages in the 'collection_sheet' data. This is because there are 6 duplicate languages in the 'OCSEAN_language_collection_overview_April_25.xlsx' file.
#
# Moreover, since the 'Kelon' and 'Klon' languages is just one language (they have the same QC filename at least according to the 'OCSEAN_language_collection_overview_April_25.xlsx' and 'OCSEAN_language_collection_overview_June_25.xlsx' collection sheets). This means that we have to deduct 1 in the summaries above (specifically in the 'Rows with QC files'). So now, there is only 80-1=79 languages with QC files.

# %% [markdown]
# # Add columns 'Has_IPA' and 'Has_English' to the languages that has QC
# for languages having IPA and English columns, respectively

# %%
clean_sheet = clean_sheet.copy()
clean_sheet.loc[:, "Has_IPA"] = False                                # Assume all languages has no IPA
clean_sheet.loc[:, "Has_English"] = False                            # Assume all languages has no English language

# Initialize tracking sets for different combinations
languages_both = set()      # Languages with both IPA and English
languages_ipa_only = set()  # Languages with IPA only
languages_eng_only = set()  # Languages with English only
languages_neither = set()   # Languages with neither

for id in clean_sheet.index:
    langname = clean_sheet.at[id, "Language_BasedOnMasterSheet"]
    
    if pd.isna(langname) or langname not in colnames:                   # Skip language if NA or not in 'colnames' data above
        continue
        
    cols = colnames[langname]                                           # Get the list of column names for this specific language
    has_ipa = 'IPA' in cols
    has_english = 'English' in cols
    
    clean_sheet.loc[id, "Has_IPA"] = has_ipa                           # Replaces False by True if the term 'IPA' is found
    clean_sheet.loc[id, "Has_English"] = has_english                   # Replaces False by True if the term 'English' is found
    
    # Categorize languages based on what columns they have
    if has_ipa and has_english:
        languages_both.add(langname)
    elif has_ipa and not has_english:
        languages_ipa_only.add(langname)
    elif not has_ipa and has_english:
        languages_eng_only.add(langname)
    else:
        languages_neither.add(langname)

# Create separated dataframes for languages that has English and has no English
has_english_sheet = clean_sheet[clean_sheet["Has_English"] == True]    # With English
no_english_sheet  = clean_sheet[clean_sheet["Has_English"] == False]   # Without English

# Convert sets to sorted lists
languages_both_list = sorted(list(languages_both))
languages_ipa_only_list = sorted(list(languages_ipa_only))
languages_eng_only_list = sorted(list(languages_eng_only))
languages_neither_list = sorted(list(languages_neither))

# Print results
print(f"Languages with IPA and English (n = {len(languages_both_list)}):")
print(", ".join(languages_both_list) if languages_both_list else "None")

print(f"\nLanguages with IPA only (n = {len(languages_ipa_only_list)}):")
print(", ".join(languages_ipa_only_list) if languages_ipa_only_list else "None")

print(f"\nLanguages with English only (n = {len(languages_eng_only_list)}):")
print(", ".join(languages_eng_only_list) if languages_eng_only_list else "None")

print(f"\nLanguages with neither IPA nor English (n = {len(languages_neither_list)}):")
print(", ".join(languages_neither_list) if languages_neither_list else "None")

print(f"\nSummary:")
print(f"- Total languages processed: {len(languages_both) + len(languages_ipa_only) + len(languages_eng_only) + len(languages_neither)}")
print(f"- Languages with IPA column: {len(languages_both) + len(languages_ipa_only)}")
print(f"- Languages with English column: {len(languages_both) + len(languages_eng_only)}")
# Out:
# Languages with IPA and English (n = 12):
# Abui Bunggeta, Ba'a, Enggano, Hiligaynon_20220813, Ibaloy/ Ibaloi, Ivatan Isabtangan, Ivatan Itbayaten / Ivatan_Ichbayatan, Mawesdai, Sabu Seba, Sinurigaonon, Tagakaulo, Tuwali
#
# Languages with IPA only (n = 1):
# Ibanag
#
# Languages with English only (n = 67):
# Abui Kilakawada, Abui Mobyetang, Abui Pelman, Adang, Agta, Agusan Manobo, Agutaynen, Akeanon, Alurung, Arta, Ata, Ati, Balangao, Bali Aga, Balinese, Batak, Bicolano, Boholano, Bolinao, Bontoc, Buhid, Bulus, Chabacano Caviteño , Cuyunon, Dela, Gaddang, Hanunuo, Hattang Kaye, Hiligaynon_20240802, Ilognon (Hiligaynon), Ilokano, Inabaknon, Kalinga, Kamayo, Kankana-ey, Kapampangan, Kelon, Kinaray-a, Klon, Kolibogan, Kupang Malay, Kusa, Loloan Malay, Manea, Manobo Tasaday, Mauta, Mawes Wares, Meranao, Minamanwa, Molbog, Obo Manobo, Palawano, Pangasinan, Reta Ternate, Sabu Raijua, Sangil, Sinama Banguingui, Sinama Sitangkai, Sinama Tabawan, Tagbanua Central, Talaandig (Binukid), Tausug, Tboli, Uab Meto, Umbu-Ungu, Waray, Yakan
#
# Languages with neither IPA nor English (n = 0):
# None
#
# Summary:
# - Total languages processed: 80
# - Languages with IPA column: 13
# - Languages with English column: 79

# %% [markdown]
# Like in the 'Add a column 'Has_QC_File' and 'File_Source'' section above:
#
# Moreover, since the 'Kelon' and 'Klon' languages is just one language (they have the same QC filename at least according to the 'OCSEAN_language_collection_overview_April_25.xlsx' and 'OCSEAN_language_collection_overview_June_25.xlsx' collection sheets). This means that we have to deduct 1 in the summaries above (specifically in the 'Languages with English column'). So now, there is only 79-1=78 languages with English column.

# %% [markdown]
# # Here's the revised collection_sheet, now containing the 'Has_QC_File,' 'File_Source,' 'Has_IPA,' and 'Has_English' columns
# and export to Excel for safekeeping

# %%
# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_language_collection_overview_June_25_new.xlsx"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    clean_sheet.to_excel(output_file_path, index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")

clean_sheet
# Out:
# File 'OCSEAN_language_collection_overview_June_25_new.xlsx' exported successfully to 'Pipeline results' folder.
#     Language_BasedOnMasterSheet ISO code (from Original_FileName)  \
# 0                 Abui Bunggeta                               ABZ
# 1               Abui Kilakawada                               ABZ
# 2                Abui Mobyetang                               ABZ
# 3                   Abui Pelman                               ABZ
# 7                         Adang                               ADN
# ..                          ...                               ...
# 115                      Tuwali                               IFK
# 116                    Uab Meto                               AOZ
# 118                   Umbu-Ungu                               NaN
# 119                       Waray                               WAR
# 121                       Yakan                               YKA
#
#               COUNTRY  LocalWordsPresent QC_done  \
# 0           Indonesia              604.0     Yes
# 1           Indonesia              604.0     Yes
# 2           Indonesia              602.0     Yes
# 3           Indonesia              602.0     Yes
# 7           Indonesia              234.0     Yes
# ..                ...                ...     ...
# 115   the Phillipines              691.0     Yes
# 116         Indonesia              991.0     Yes
# 118  Papua New Guinea                NaN     NaN
# 119   the Phillipines             1178.0     Yes
# 121   the Phillipines             1129.0     Yes
#
#     AddedToTheUnitedLanguagesMasterFile  \
# 0                                   Yes
# 1                                   Yes
# 2                                   Yes
# 3                                   Yes
# 7                                   Yes
# ..                                  ...
# 115                                 Yes
# 116                                 Yes
# 118                                 NaN
# 119                             Not yet
# 121                             Not Yet
#
#                                                Comment  \
# 0    Some English and or Indonesian words in this l...
# 1    English and English Elicitation notes complete...
# 2    English Elicitation = English actually. Some E...
# 3    English Elicitation = English actually. Some E...
# 7    The formatting of indonesian words in this lan...
# ..                                                 ...
# 115  I used wordlist2 because it had 3-4x more word...
# 116  English/Indonesian seems to be identical to re...
# 118                                                NaN
# 119  English Tagalog available, no Indonesian. No s...
# 121  Lowered cases, Indonesian available. English/I...
#
#                                              Separator  Mismatches_Eng  \
# 0                 , and ; and ~ (?). Only used , and ;            41.0
# 1                 , and ; and ~ (?). Only used , and ;            41.0
# 2                 , and ; and ~ (?). Only used , and ;            41.0
# 3                 , and ; and ~ (?). Only used , and ;            41.0
# 7                                                    ,             NaN
# ..                                                 ...             ...
# 115  Space? Should be rechecked by someone. Did not...             1.0
# 116                                                  /             0.0
# 118                                                NaN             NaN
# 119                             space? Didn’t separate             0.0
# 121                                     , (and space?)             0.0
#
#      Mismatches_IndoOrTaga                             Original_FileName  \
# 0                     87.0    OCSEAN-ABZ_20240605-BUNGGETA_WORDLIST.xlsx
# 1                     87.0  OCSEAN-ABZ_20240606-KILAKAWADA_WORDLIST.xlsx
# 2                     87.0   OCSEAN-ABZ_20240610-MOBYETANG_WORDLIST.xlsx
# 3                     87.0      OCSEAN-ABZ_20240610-PELMAN_WORDLIST.xlsx
# 7                     67.0             OCSEAN-ADN_20230427-WORDLIST.xlsx
# ..                     ...                                           ...
# 115                    3.0    OCSEAN-IFK_20220715-WORDLIST2_1TO1228.xlsx
# 116                    0.0                    AOZ_20220715-WORDLIST.xlsx
# 118                    NaN                                           NaN
# 119                    1.0     OCSEAN-WAR_20240407-WORDLIST_1TO1228.xlsx
# 121                    0.0     OCSEAN-YKA_20240324-WORDLIST_1TO1228.xlsx
#
#                                            QC_FileName  \
# 0    OCSEAN-ABZ_20240605-BUNGGETA_WORDLIST_PostQC.xlsx
# 1    OCSEAN-ABZ_20240606-KILAKAWADA_WORDLIST_PostQC...
# 2    OCSEAN-ABZ_20240610-MOBYETANG_WORDLIST_PostQC....
# 3      OCSEAN-ABZ_20240610-PELMAN_WORDLIST_PostQC.xlsx
# 7             OCSEAN-ADN_20230427-WORDLIST_PostQC.xlsx
# ..                                                 ...
# 115  OCSEAN-IFK_20220715-WORDLIST2_1TO1228_PostQC.xlsx
# 116                  AOZ_20220715-WORDLIST_PostQC.xlsx
# 118           OCSEAN-UBU_20240802-WORDLIST_PostQC.xlsx
# 119   OCSEAN-WAR_20240407-WORDLIST_1TO1228_PostQC.xlsx
# 121   OCSEAN-YKA_20240324-WORDLIST_1TO1228_PostQC.xlsx
#
#                       Google Map Coordinate   latitude   longitude  \
# 0                                       NaN        NaN         NaN
# 1                                       NaN        NaN         NaN
# 2                                       NaN        NaN         NaN
# 3                                       NaN        NaN         NaN
# 7                                       NaN        NaN         NaN
# ..                                      ...        ...         ...
# 115                                     NaN        NaN         NaN
# 116                                     NaN        NaN         NaN
# 118                                     NaN        NaN         NaN
# 119  12.312908225545875, 125.01703265863979  12.312908  125.017033
# 121                    6.898960, 122.087217   6.898960  122.087217
#
#      Has_QC_File        File_Source  Has_IPA  Has_English
# 0           True  CleanedFiles-v1.1     True         True
# 1           True  CleanedFiles-v1.1    False         True
# 2           True  CleanedFiles-v1.1    False         True
# 3           True       CleanedFiles    False         True
# 7           True  CleanedFiles-v1.1    False         True
# ..           ...                ...      ...          ...
# 115         True  CleanedFiles-v1.1     True         True
# 116         True       CleanedFiles    False         True
# 118         True  CleanedFiles-v1.1    False         True
# 119         True  CleanedFiles-v1.1    False         True
# 121         True  CleanedFiles-v1.1    False         True
#
# [80 rows x 19 columns]

# %% [markdown]
# # Extracting information about columns
# In the 'Add a column 'Has_QC_File' and 'File_Source'' section above, we stored all of the column names of the 'collection' dictionary of all Excel files.
#
# The goal of the code below is to check

# %%
all_cols = [col for sublist in colnames.values() for col in sublist]
counter = Counter(all_cols)
for item, count in counter.items():
    if count > 1:
        print(f"{item}: {count}")
# Out:
# English: 79
# Indonesian: 37
# IPA: 13
# Semantic Sphere: 4
# Tagalog: 57
# ENGLISH ELICITATION NOTES: 7
# CEBUANO: 5
# Kamayo: 2
# Talaandig: 2
# Semantic_Field: 24
# English elicitation notes: 21
# Indonesian elicitation notes: 17
# Cebuano: 15
# Tagalog Elicitation Notes: 3
# Ontology: 3
# Ilocano: 12
# Local Orthography: 4
# Comment: 3
# Hiligaynon: 2
# NO.: 2
# Kelon: 2
# Sangil: 2
# Local language: 2

# %% [markdown]
# # Merging datasets using Languages that has English

# %%
# Fix the copy warning by making has_english_sheet independent
has_english_sheet = has_english_sheet.copy()

# Step 1: Find actual language column names using fuzzy matching (vectorized)
# Apply fuzzy matching to all rows at once instead of looping
has_english_sheet["Language_AsInFile"] = has_english_sheet["Language_BasedOnMasterSheet"].apply(
    lambda lang: process.extractOne(lang, colnames[lang])[0]
)

# Step 2: Create standardized DataFrames and combine in one step
# Use dictionary comprehension to replace the entire loop
joinable_collection = {
    # For each row, create a standardized DataFrame
    row["Language_BasedOnMasterSheet"]: (
        collection[row["Language_BasedOnMasterSheet"]]  # Get the original DataFrame
        [["English", row["Language_AsInFile"]]]         # Select only needed columns
        .rename(columns={                               # Rename to standard names
            "English": "Concept", 
            row["Language_AsInFile"]: "Word"
        })
        .assign(Language=row["Language_AsInFile"])      # Add Language column
        .dropna()                                       # Remove missing values
    )
    # Apply this to each row in has_english_sheet
    for _, row in has_english_sheet.iterrows()
}

# Step 3: Combine all languages into one dataset
# Stack all DataFrames vertically with continuous indexing
joined_data = pd.concat(joinable_collection.values(), axis=0, ignore_index=True).drop_duplicates()

# Convert 'Concept' and 'Word' columns to lowercase
joined_data['Concept'] = joined_data['Concept'].str.lower()
joined_data['Word'] = joined_data['Word'].str.lower()

# %%
has_english_sheet
# Out:
#     Language_BasedOnMasterSheet ISO code (from Original_FileName)  \
# 0                 Abui Bunggeta                               ABZ
# 1               Abui Kilakawada                               ABZ
# 2                Abui Mobyetang                               ABZ
# 3                   Abui Pelman                               ABZ
# 7                         Adang                               ADN
# ..                          ...                               ...
# 115                      Tuwali                               IFK
# 116                    Uab Meto                               AOZ
# 118                   Umbu-Ungu                               NaN
# 119                       Waray                               WAR
# 121                       Yakan                               YKA
#
#               COUNTRY  LocalWordsPresent QC_done  \
# 0           Indonesia              604.0     Yes
# 1           Indonesia              604.0     Yes
# 2           Indonesia              602.0     Yes
# 3           Indonesia              602.0     Yes
# 7           Indonesia              234.0     Yes
# ..                ...                ...     ...
# 115   the Phillipines              691.0     Yes
# 116         Indonesia              991.0     Yes
# 118  Papua New Guinea                NaN     NaN
# 119   the Phillipines             1178.0     Yes
# 121   the Phillipines             1129.0     Yes
#
#     AddedToTheUnitedLanguagesMasterFile  \
# 0                                   Yes
# 1                                   Yes
# 2                                   Yes
# 3                                   Yes
# 7                                   Yes
# ..                                  ...
# 115                                 Yes
# 116                                 Yes
# 118                                 NaN
# 119                             Not yet
# 121                             Not Yet
#
#                                                Comment  \
# 0    Some English and or Indonesian words in this l...
# 1    English and English Elicitation notes complete...
# 2    English Elicitation = English actually. Some E...
# 3    English Elicitation = English actually. Some E...
# 7    The formatting of indonesian words in this lan...
# ..                                                 ...
# 115  I used wordlist2 because it had 3-4x more word...
# 116  English/Indonesian seems to be identical to re...
# 118                                                NaN
# 119  English Tagalog available, no Indonesian. No s...
# 121  Lowered cases, Indonesian available. English/I...
#
#                                              Separator  Mismatches_Eng  \
# 0                 , and ; and ~ (?). Only used , and ;            41.0
# 1                 , and ; and ~ (?). Only used , and ;            41.0
# 2                 , and ; and ~ (?). Only used , and ;            41.0
# 3                 , and ; and ~ (?). Only used , and ;            41.0
# 7                                                    ,             NaN
# ..                                                 ...             ...
# 115  Space? Should be rechecked by someone. Did not...             1.0
# 116                                                  /             0.0
# 118                                                NaN             NaN
# 119                             space? Didn’t separate             0.0
# 121                                     , (and space?)             0.0
#
#      Mismatches_IndoOrTaga                             Original_FileName  \
# 0                     87.0    OCSEAN-ABZ_20240605-BUNGGETA_WORDLIST.xlsx
# 1                     87.0  OCSEAN-ABZ_20240606-KILAKAWADA_WORDLIST.xlsx
# 2                     87.0   OCSEAN-ABZ_20240610-MOBYETANG_WORDLIST.xlsx
# 3                     87.0      OCSEAN-ABZ_20240610-PELMAN_WORDLIST.xlsx
# 7                     67.0             OCSEAN-ADN_20230427-WORDLIST.xlsx
# ..                     ...                                           ...
# 115                    3.0    OCSEAN-IFK_20220715-WORDLIST2_1TO1228.xlsx
# 116                    0.0                    AOZ_20220715-WORDLIST.xlsx
# 118                    NaN                                           NaN
# 119                    1.0     OCSEAN-WAR_20240407-WORDLIST_1TO1228.xlsx
# 121                    0.0     OCSEAN-YKA_20240324-WORDLIST_1TO1228.xlsx
#
#                                            QC_FileName  \
# 0    OCSEAN-ABZ_20240605-BUNGGETA_WORDLIST_PostQC.xlsx
# 1    OCSEAN-ABZ_20240606-KILAKAWADA_WORDLIST_PostQC...
# 2    OCSEAN-ABZ_20240610-MOBYETANG_WORDLIST_PostQC....
# 3      OCSEAN-ABZ_20240610-PELMAN_WORDLIST_PostQC.xlsx
# 7             OCSEAN-ADN_20230427-WORDLIST_PostQC.xlsx
# ..                                                 ...
# 115  OCSEAN-IFK_20220715-WORDLIST2_1TO1228_PostQC.xlsx
# 116                  AOZ_20220715-WORDLIST_PostQC.xlsx
# 118           OCSEAN-UBU_20240802-WORDLIST_PostQC.xlsx
# 119   OCSEAN-WAR_20240407-WORDLIST_1TO1228_PostQC.xlsx
# 121   OCSEAN-YKA_20240324-WORDLIST_1TO1228_PostQC.xlsx
#
#                       Google Map Coordinate   latitude   longitude  \
# 0                                       NaN        NaN         NaN
# 1                                       NaN        NaN         NaN
# 2                                       NaN        NaN         NaN
# 3                                       NaN        NaN         NaN
# 7                                       NaN        NaN         NaN
# ..                                      ...        ...         ...
# 115                                     NaN        NaN         NaN
# 116                                     NaN        NaN         NaN
# 118                                     NaN        NaN         NaN
# 119  12.312908225545875, 125.01703265863979  12.312908  125.017033
# 121                    6.898960, 122.087217   6.898960  122.087217
#
#      Has_QC_File        File_Source  Has_IPA  Has_English Language_AsInFile
# 0           True  CleanedFiles-v1.1     True         True     Abui_Bunggeta
# 1           True  CleanedFiles-v1.1    False         True   Abui_Kilakawada
# 2           True  CleanedFiles-v1.1    False         True    Abui_Mobyetang
# 3           True       CleanedFiles    False         True       Abui_Pelman
# 7           True  CleanedFiles-v1.1    False         True             Adang
# ..           ...                ...      ...          ...               ...
# 115         True  CleanedFiles-v1.1     True         True            Tuwali
# 116         True       CleanedFiles    False         True          Uab_Meto
# 118         True  CleanedFiles-v1.1    False         True         Umbu-Ungu
# 119         True  CleanedFiles-v1.1    False         True             Waray
# 121         True  CleanedFiles-v1.1    False         True             Yakan
#
# [79 rows x 20 columns]

# %%
# Create a dictionary to store language counts
language_counts = defaultdict(int)

# Iterate through each row in the DataFrame
for index, row in has_english_sheet.iterrows():
    languages_str = row['COUNTRY']
    # Split the languages string by comma and strip whitespace
    languages = [lang.strip() for lang in languages_str.split(',')]

    # For each language associated with the rare concept, increment its count
    for lang in languages:
        language_counts[lang] += 1

# Convert the dictionary to a pandas Series for easier plotting
language_counts_series = pd.Series(language_counts).sort_values(ascending=False)

# Plotting the results
plt.figure(figsize=(20, 8))
ax = sns.barplot(x=language_counts_series.index, y=language_counts_series.values)
plt.title('Number of Languages per Country')
plt.xlabel('Country')
plt.ylabel('Number of Languages')
plt.xticks(rotation=00, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Add labels on top of each bar
total_count = language_counts_series.sum()
for p in ax.patches:
    count = int(p.get_height())
    percentage = (count / total_count) * 100
    ax.annotate(f'{count} ({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                fontsize=8, color='black',
                xytext=(0, 5), textcoords='offset points')

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'languages_per_country_bar_plot.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

plt.show()

# %%
# Create a dictionary to store country counts
country_counts = defaultdict(int)

# Iterate through each row in the DataFrame
for index, row in has_english_sheet.iterrows():
    countries_str = row['COUNTRY']
    # Split the countries string by comma and strip whitespace
    countries = [country.strip() for country in countries_str.split(',')]

    # For each country, increment its count
    for country in countries:
        country_counts[country] += 1

# Convert the dictionary to a pandas Series for easier plotting
country_counts_series = pd.Series(country_counts).sort_values(ascending=False)

# Calculate percentages for the labels
total_count = country_counts_series.sum()
labels_with_percentage = [
    f"{country} (n = {count}; {((count / total_count) * 100):.1f}%)"
    for country, count in country_counts_series.items()
]

# Define your custom colors
# You only want 3 colors, so we'll use them. If you have more slices than colors,
# Matplotlib will cycle through them or use default colors for the rest.
custom_colors = ["#4682B4", "#00a2c8", "#00c0c3"]

# --- Plotting the Pie Chart ---
plt.figure(figsize=(20, 10)) # Adjust figure size for better pie chart presentation
plt.pie(
    country_counts_series.values,
    labels=labels_with_percentage, # Use the new labels with count and percentage
    colors=custom_colors[:len(country_counts_series)], # Apply custom colors up to the number of slices
    startangle=90, # Start the first slice at the top
    pctdistance=0.85 # Distance of percentage labels from the center (not strictly needed with custom labels)
)
plt.title('', fontsize=16) # Added a more descriptive title
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'languages_per_country_pie_chart.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

plt.show()

# %% [markdown]
# # Rare Concepts Detection

# %%
# Create a DataFrame to store results
matched_concepts = []

concept_counts  = joined_data["Concept"].value_counts()
common_concepts = concept_counts[concept_counts>=25].index.tolist()
rare_concepts   = concept_counts[concept_counts<25].index.tolist()

# For each rare concept, find the best match from common_concepts
for concept in rare_concepts:
    best_match, score = process.extractOne(concept, common_concepts)
    top_matches = process.extract(concept, common_concepts, limit=5)
    matched_concepts.append({
        'rare_concept': concept,
        'count': concept_counts[concept],
        'best_match': best_match,
        'similarity_score': score,
        'languages':",".join(list(joined_data['Language'][joined_data['Concept']==concept])),
        'top_matches':",".join([x[0] for x in top_matches])
    })

# Convert to DataFrame for display
matched_df = pd.DataFrame(matched_concepts)

# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_rareconcepts_matching.xlsx"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    matched_df.to_excel(output_file_path, index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")

# Show the result
matched_df
# Out:
# File 'OCSEAN_rareconcepts_matching.xlsx' exported successfully to 'Pipeline results' folder.
#                                rare_concept  count        best_match  \
# 0     mound of stones for ritual activities     24             stone
# 1                    jew's harp, mouth harp     22             mouth
# 2                            casuarina tree     22              tree
# 3                                    cuscus     21               cut
# 4                      gum tree, eucalyptus     21              tree
# ...                                     ...    ...               ...
# 1399                                  truth      1  dust, fine earth
# 1400                                  about      1               cut
# 1401                              yard/page      1              year
# 1402                               delicate      1               cat
# 1403                              peanuts        1           peanuts
#
#       similarity_score                                          languages  \
# 0                   90  Abui_Bunggeta,Abui_Bunggeta,Abui_Kilakawada,Ab...
# 1                   90  Agusan_Manobo,Arta,Ata,Ba_a,Balinese,Bicolano,...
# 2                   90  Agusan_Manobo,Arta,Ba_a,Balinese,Bicolano,Boho...
# 3                   72  Abui_Bunggeta,Abui_Kilakawada,Abui_Mobyetang,A...
# 4                   90  Agusan_Manobo,Arta,Ba_a,Balinese,Boholano,Buhi...
# ...                ...                                                ...
# 1399                68                                       Loloan_Malay
# 1400                72                                       Loloan_Malay
# 1401                77                                       Loloan_Malay
# 1402                90                                       Loloan_Malay
# 1403               100                                          Umbu-Ungu
#
#                                             top_matches
# 0     stone,in front of,look for, seek,palm of hand,...
# 1                    mouth,adam's apple,sharp,hair,hear
# 2                              tree,three,eye,urine,see
# 3                           cut,use,snot, mucus,cup,pus
# 4     tree,bark (of tree),moringa tree,banyan tree,gums
# ...                                                 ...
# 1399  dust, fine earth,placenta, afterbirth,run,cut,rub
# 1400        cut,call out,butterfly,buttocks,tight, taut
# 1401                           year,red,pay,eagle,guard
# 1402                            cat,at,defecate,die,ten
# 1403                     peanuts,guts,anus,parents,open
#
# [1404 rows x 6 columns]

# %% [markdown]
# Above are concepts that are considered to be 'rare.' Although the definition of rarity is frivolous in nature. We set it to be less than 25, i.e., if the concept only appears less than 25 times in all the 70,000+ concepts, then it is considered a rare concept.

# %%
# Create a dictionary to store language counts
language_rare_concept_counts = defaultdict(int)

# Iterate through each row in the DataFrame
for index, row in matched_df.iterrows():
    languages_str = row['languages']
    # Split the languages string by comma and strip whitespace
    languages = [lang.strip() for lang in languages_str.split(',')]

    # For each language associated with the rare concept, increment its count
    for lang in languages:
        language_rare_concept_counts[lang] += 1

# Convert the dictionary to a pandas Series for easier plotting
language_counts_series = pd.Series(language_rare_concept_counts).sort_values(ascending=False)

# Plotting the results
plt.figure(figsize=(20, 8))
ax = sns.barplot(x=language_counts_series.index, y=language_counts_series.values)
plt.title('Number of Rare Concepts per Language')
plt.xlabel('Language')
plt.ylabel('Number of Rare Concepts')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Add labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                fontsize=8, color='black',
                xytext=(0, 5), textcoords='offset points')

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'rare_concepts_per_language.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

plt.show()

# %%
# Calculate the frequency of each number
# value_counts() sorts in descending order by default,
# but for a bar plot showing counts 1-24, it's better to sort by index (the count values)
frequency = matched_df['count'].value_counts().sort_index()

# Create the bar plot
fig, ax = plt.subplots(figsize=(20, 8)) # Adjust figure size for better readability and get the axes object
ax.bar(frequency.index, frequency.values, color='steelblue')

# Add labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                fontsize=8, color='black',
                xytext=(0, 5), textcoords='offset points')

# Add labels and title using the axes object
ax.set_xlabel("Count Value")
ax.set_ylabel("Frequency")
ax.set_title("Frequency Distribution of 'counts' Column")
ax.set_xticks(np.arange(1, 25, 1)) # Ensure all integer ticks from 1 to 24 are shown
#ax.grid(axis='y', linestyle='--', alpha=0.7) # Add a grid for better readability

# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# Define the path to save the plot
os.makedirs(results_folder_name, exist_ok=True) # Create the folder if it doesn't exist
plot_path = os.path.join(results_folder_name, 'histogram_rare_concepts.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

print(f"Bar plot saved to {plot_path}")
# Out:
# Bar plot saved to Pipeline results/histogram_rare_concepts.png

# %% [markdown]
# # Rare Concept Correction
# using the 'OCSEAN_rareconcepts_matching.xlsx' file that was last modified on June 13, 2025. Stored in 'joined_data_updated' variable.

# %%
# Copy the rare concepts
matching_df = pd.read_excel(os.path.join("Metadata","OCSEAN_rareconcepts_matching_correction.xlsx"))

# Display the structure of the matching file for verification
print("Matching file structure:")
#print(matching_df.head())
print(f"Shape: {matching_df.shape}")
#print("\nColumns:", matching_df.columns.tolist())

print("\nJoined data structure:")
print(joined_data.head())
print(f"Shape: {joined_data.shape}")

# Create a mapping dictionary from the Excel file
# Only include rows where 'best_match' is not empty/null
mapping_dict = {}

for idx, row in matching_df.iterrows():
    rare_concept = row['rare_concept']
    best_match = row['best_match']
    
    # Check if best_match is not empty/null
    if pd.notna(best_match) and str(best_match).strip() != '':
        mapping_dict[rare_concept] = best_match
        #print(f"Mapping: '{rare_concept}' -> '{best_match}'")

print(f"\nTotal unique replacements made: {len(mapping_dict)}")

# Apply the replacement to the joined_data
# Create a copy to preserve the original data
joined_data_updated = joined_data.copy()

# Track changes for reporting
changes_made = 0
original_concepts = []
new_concepts = []

for idx, row in joined_data_updated.iterrows():
    current_concept = row['Concept']
    
    # Check if current concept should be replaced
    if current_concept in mapping_dict:
        new_concept = mapping_dict[current_concept]
        joined_data_updated.at[idx, 'Concept'] = new_concept
        
        # Track the change
        changes_made += 1
        original_concepts.append(current_concept)
        new_concepts.append(new_concept)
        
        #print(f"Row {idx}: Changed '{current_concept}' to '{new_concept}'")

# Summary of changes
print(f"\n=== SUMMARY ===")
print(f"Total rows processed: {len(joined_data)}")
print(f"Total changes made: {changes_made}")

if changes_made > 0:
    print("\nChanges made:")
    for i in range(min(10, len(original_concepts))):  # Show first 10 changes
        print(f"  '{original_concepts[i]}' -> '{new_concepts[i]}'")
    
    if changes_made > 10:
        print(f"  ... and {changes_made - 10} more changes")
# Out:
# Matching file structure:
# Shape: (1404, 7)
#
# Joined data structure:
#   Concept         Word       Language
# 0     sun        wariy  Abui_Bunggeta
# 1    moon         'uya  Abui_Bunggeta
# 2    star        furiy  Abui_Bunggeta
# 3     sky       'adiiy  Abui_Bunggeta
# 4   earth  buku; bukuw  Abui_Bunggeta
# Shape: (76255, 3)
#
# Total unique replacements made: 634
#
# === SUMMARY ===
# Total rows processed: 76255
# Total changes made: 1349
#
# Changes made:
#   'dust' -> 'dust, fine earth'
#   'dawn' -> 'twilight, dawn'
#   'dawn' -> 'twilight, dawn'
#   'road, path' -> 'road'
#   'sail (v.)' -> 'sail'
#   'sail (v.)' -> 'sail'
#   'castnet' -> 'fishnet'
#   'thatch for making rooves' -> 'thatch, reed or grass used for making roofs'
#   'thatch for making rooves' -> 'thatch, reed or grass used for making roofs'
#   'roof rafter (lengthwise)' -> 'rafter'
#   ... and 1339 more changes

# %% [markdown]
# You'll notice that the **'Total unique replacements made'** is not the same as the **'Total changes made.'** This is because there are **duplicate concepts** which has been counted as separate in the 'Total changes made' count.

# %% [markdown]
# # Here's the data that will be used later on for lingpy data preprocessing and analysis

# %%
joined_data_updated
# Out:
#                Concept         Word       Language
# 0                  sun        wariy  Abui_Bunggeta
# 1                 moon         'uya  Abui_Bunggeta
# 2                 star        furiy  Abui_Bunggeta
# 3                  sky       'adiiy  Abui_Bunggeta
# 4                earth  buku; bukuw  Abui_Bunggeta
# ...                ...          ...            ...
# 76678             imam         imam          Yakan
# 76679            bless      ridjiki          Yakan
# 76680           redeem       tawbat          Yakan
# 76681            curse       nukna'          Yakan
# 76682  sorcerer, witch   palkata'an          Yakan
#
# [76255 rows x 3 columns]

# %% [markdown]
# # Export to Excel

# %%
# Export has_english_sheet

# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_initial_englishsheet.xlsx"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    has_english_sheet.replace({True: 'TRUE', False: 'FALSE'}).to_excel(output_file_path, index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")

# Export collection_sheet

# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_initial_collectionsheet.xlsx"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    collection_sheet.replace({True: 'TRUE', False: 'FALSE'}).to_excel(output_file_path, index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")
# Out:
# File 'OCSEAN_initial_englishsheet.xlsx' exported successfully to 'Pipeline results' folder.
# File 'OCSEAN_initial_collectionsheet.xlsx' exported successfully to 'Pipeline results' folder.

# %%
# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_initial_joineddata.tsv"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    joined_data_updated.to_csv(output_file_path, sep='\t', index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")
# Out:
# File 'OCSEAN_initial_joineddata.tsv' exported successfully to 'Pipeline results' folder.

# %% [markdown]
# # on lingpy
#
# In this code we are interested in checking whether our data are compatible with `lingpy` as this is the pipeline we will use later for analysing words.

# %% [markdown]
# # Load data
# Load first in 'CleanedFiles-v1.1' and if the file is not existent, then load from 'CleanedFiles'

# %%
file_path = os.path.join(results_folder_name, 'OCSEAN_initial_joineddata.tsv')

od = pd.read_table(file_path)
od = od[['Concept','Word','Language']] # Specifying columns also records them in the dataframe
od = od.dropna() # Remove if there were NaN's
od = od.drop_duplicates() # Remove if there were duplicates

# Here's the data
od
# Out:
#                Concept         Word       Language
# 0                  sun        wariy  Abui_Bunggeta
# 1                 moon         'uya  Abui_Bunggeta
# 2                 star        furiy  Abui_Bunggeta
# 3                  sky       'adiiy  Abui_Bunggeta
# 4                earth  buku; bukuw  Abui_Bunggeta
# ...                ...          ...            ...
# 76250             imam         imam          Yakan
# 76251            bless      ridjiki          Yakan
# 76252           redeem       tawbat          Yakan
# 76253            curse       nukna'          Yakan
# 76254  sorcerer, witch   palkata'an          Yakan
#
# [76253 rows x 3 columns]

# %% [markdown]
# # Split into Multiple Rows if a 'form' has delimiters such as , and ; and / and ~
#
# This is in the case when there are forms that have 1 form but has multiple concepts. We make separate rows of each.
#
# Example:
#
# - Concept | Form
# - cave    | yungib,kuweba
#
# Will become 2 rows
#
# - cave | yungib
# - cave | kuweba

# %%
# Clean and optionally split into Multiple Rows if a 'form' has delimiters such as , and ; and / and ~
def clean_and_split_forms(df, column_name='Word', delimiters='default', split_on_delimiters=True, 
                          verbose=True, normalize_spaces=True, remove_tabs=True, remove_newlines=True, 
                          remove_carriage_returns=True, remove_non_breaking_spaces=True,
                          export_excel=False, filename='data_processing_results'):
    """
    Clean and optionally split a DataFrame column containing delimited text.
    
    Args:
        df (pd.DataFrame): Input DataFrame
        column_name (str): Name of column to process
        delimiters (list): List of delimiters to replace with commas. 
                          Defaults to [';', '/', '~']
        split_on_delimiters (bool): If True, splits on delimiters and creates multiple rows.
                                   If False, only performs cleaning operations.
        verbose (bool): Whether to print progress information
        normalize_spaces (bool): If True, replaces multiple consecutive spaces with single spaces
        remove_tabs (bool): If True, removes tab characters (\t)
        remove_newlines (bool): If True, removes newline characters (\n)
        remove_carriage_returns (bool): If True, removes carriage return characters (\r)
        remove_non_breaking_spaces (bool): If True, removes non-breaking spaces (\xa0)
        export_excel (bool): If True, exports processing stages to Excel file
        filename (str): Base filename for Excel export (timestamp will be added)
    
    Returns:
        pd.DataFrame: Processed DataFrame with cleaned and optionally split forms
    """
    if delimiters == 'default':
        delimiters = [';', '/', '~']#, '|', '\\', '&']
    
    # Store original data for export
    original_data = df.copy()
    
    # Create a copy to avoid modifying original
    result_df = df.copy()
    
    if verbose:
        print(f'Original number of rows: {len(original_data)}')
        if split_on_delimiters:
            print('Mode: Cleaning and splitting on delimiters')
        else:
            print('Mode: Cleaning only (no delimiter splitting)')
    
    # 1. First, clean whitespace characters before processing
    if remove_tabs:
        result_df[column_name] = result_df[column_name].str.replace('\t', ' ', regex=False)
    if remove_newlines:
        result_df[column_name] = result_df[column_name].str.replace('\n', ' ', regex=False)
    if remove_carriage_returns:
        result_df[column_name] = result_df[column_name].str.replace('\r', ' ', regex=False)
    if remove_non_breaking_spaces:
        result_df[column_name] = result_df[column_name].str.replace('\xa0', ' ', regex=False)
    
    # Normalize multiple spaces to single spaces
    if normalize_spaces:
        result_df[column_name] = result_df[column_name].str.replace(r'\s+', ' ', regex=True)
    
    # 2. Strip any leading/trailing whitespace after normalization
    result_df[column_name] = result_df[column_name].str.strip()
    
    # 3. Handle delimiter processing based on mode
    if split_on_delimiters:
        # Normalize delimiters - replace all with commas
        for delimiter in delimiters:
            result_df[column_name] = result_df[column_name].str.replace(delimiter, ',', regex=False)
        
        # Clean up multiple consecutive commas and normalize whitespace around commas
        result_df[column_name] = result_df[column_name].str.replace(r',+', ',', regex=True)  # Multiple commas -> single comma
        result_df[column_name] = result_df[column_name].str.replace(r'\s*,\s*', ',', regex=True)  # Remove spaces around commas
        result_df[column_name] = result_df[column_name].str.strip(',')  # Remove leading/trailing commas
        
        # Split by comma and explode
        result_df[column_name] = result_df[column_name].str.split(',')
        exploded_data = result_df.explode(column_name).copy()  # Store exploded data for export
        result_df = result_df.explode(column_name)
        
        # Clean up the split results
        result_df[column_name] = result_df[column_name].str.strip()  # Remove whitespace
    else:
        # For cleaning-only mode, create exploded_data as a copy for consistency in export
        exploded_data = result_df.copy()
    
    # 4. Store data before removals for tracking
    before_removal = result_df.copy()
    before_removal_count = len(before_removal)
    
    # 5. Remove invalid entries (NaN and empty strings)
    result_df = result_df[result_df[column_name].notna()]  # Remove NaN
    result_df = result_df[result_df[column_name] != '']    # Remove empty strings
    after_invalid_removal_count = len(result_df)
    
    # 6. Remove duplicates 
    cleaned_data = result_df.drop_duplicates()
    after_duplicate_removal_count = len(cleaned_data)
    
    # 7. Calculate removed data by tracking each removal step
    # Find invalid entries that were removed
    invalid_removed = before_removal[
        (before_removal[column_name].isna()) | 
        (before_removal[column_name] == '')
    ].copy()
    
    # Find duplicates that were removed
    valid_data = before_removal[
        (before_removal[column_name].notna()) & 
        (before_removal[column_name] != '')
    ].copy()
    
    # Get duplicates by finding rows that appear more than once
    duplicated_mask = valid_data.duplicated(keep='first')
    duplicates_removed = valid_data[duplicated_mask].copy()
    
    # Combine all removed data
    removed_data = pd.concat([invalid_removed, duplicates_removed], ignore_index=True)
    
    # Reset index for cleaned data
    cleaned_data = cleaned_data.reset_index(drop=True)
    
    # 8. Add sequential ID to cleaned data
    cleaned_data['ID'] = range(len(cleaned_data))
    cleaned_data.set_index('ID', inplace=True)
    
    if verbose:
        print(f'Final number of rows: {cleaned_data.shape[0]}')
        if split_on_delimiters:
            print(f'Rows change: {cleaned_data.shape[0] - original_data.shape[0]} (net effect of splitting and cleaning)')
        print(f'Invalid entries removed (NA or empty): {len(invalid_removed)}')
        print(f'Duplicates removed: {len(duplicates_removed)}')
        print(f'Total rows removed during processing: {len(removed_data)}')
    
#    # 9. Export to Excel if requested
#    if export_excel:
#        # Generate timestamp in the format: MonthDayYear24HourTimeFormat
#       timestamp = datetime.now().strftime('%m%d%Y_%H%M%S')
#        excel_file_name_with_timestamp = f"{filename}_{timestamp}.xlsx"
#
#        # Construct the full path to the output Excel file
#        output_excel_path = os.path.join(results_folder_name, excel_file_name_with_timestamp)
#
#        with pd.ExcelWriter(output_excel_path, engine='openpyxl') as writer:
#            original_data.to_excel(writer, sheet_name='Original data', index=True)
#            if split_on_delimiters:
#                exploded_data.to_excel(writer, sheet_name='Exploded data', index=True)
#            else:
#                exploded_data.to_excel(writer, sheet_name='Cleaned data (pre-dedup)', index=True)
#            removed_data.to_excel(writer, sheet_name='Removed data', index=False)
#            cleaned_data.to_excel(writer, sheet_name='Final cleaned data', index=True)
#
#        if verbose:
#            print(f'Excel file exported: {output_excel_path}')
#    
#    return cleaned_data

    # 9. Export to Excel if requested
    if export_excel:
        # Generate timestamp in the format: MonthDayYear24HourTimeFormat
        timestamp = datetime.now().strftime('%m%d%Y_%H%M%S')
        excel_file_name_with_timestamp = f"{filename}_{timestamp}.xlsx"

        # Construct the full path to the output Excel file
        # This will save the Excel file inside the 'results_folder_name' directory.
        output_excel_path = os.path.join(results_folder_name, excel_file_name_with_timestamp)

        try:
            with pd.ExcelWriter(output_excel_path, engine='openpyxl') as writer:
                original_data.to_excel(writer, sheet_name='Original data', index=True)
                if split_on_delimiters:
                    exploded_data.to_excel(writer, sheet_name='Exploded data', index=True)
                else:
                    exploded_data.to_excel(writer, sheet_name='Cleaned data (pre-dedup)', index=True)
                removed_data.to_excel(writer, sheet_name='Removed data', index=False)
                cleaned_data.to_excel(writer, sheet_name='Final cleaned data', index=True)

            if verbose:
                print(f'Excel file exported: {output_excel_path}')
        except Exception as e:
            print(f"An error occurred during Excel export: {e}")
            print("Excel export failed.")

    return cleaned_data
    
# Example usage:
# For splitting on delimiters (original behavior):
# result = clean_and_split_forms(df, column_name='Word', split_on_delimiters=True)

# For cleaning only (no delimiter splitting):
# result = clean_and_split_forms(df, column_name='Word', split_on_delimiters=False)

# %%
od_exploded = clean_and_split_forms(
    df=od, 
    column_name='Word', 
    delimiters='default', 
    split_on_delimiters=True,
    verbose=True, 
    export_excel=False,                # Can take some time exporting to Excel
    filename='data_processing_results' # Will only be used when export_excel=True
)
# Out:
# Original number of rows: 76253
# Mode: Cleaning and splitting on delimiters
# Final number of rows: 76695
# Rows change: 442 (net effect of splitting and cleaning)
# Invalid entries removed (NA or empty): 4
# Duplicates removed: 2
# Total rows removed during processing: 6

# %%
od
# Out:
#                Concept         Word       Language
# 0                  sun        wariy  Abui_Bunggeta
# 1                 moon         'uya  Abui_Bunggeta
# 2                 star        furiy  Abui_Bunggeta
# 3                  sky       'adiiy  Abui_Bunggeta
# 4                earth  buku; bukuw  Abui_Bunggeta
# ...                ...          ...            ...
# 76250             imam         imam          Yakan
# 76251            bless      ridjiki          Yakan
# 76252           redeem       tawbat          Yakan
# 76253            curse       nukna'          Yakan
# 76254  sorcerer, witch   palkata'an          Yakan
#
# [76253 rows x 3 columns]

# %%
od_exploded_Concept = clean_and_split_forms(
    df=od_exploded,
    column_name='Concept', 
    delimiters='default', 
    split_on_delimiters=False,
    verbose=True, 
    export_excel=False,                # Can take some time exporting to Excel
    filename='data_processing_results' # Will only be used when export_excel=True
)

#od_exploded_Concept # Uncmomment to view
# Out:
# Original number of rows: 76695
# Mode: Cleaning only (no delimiter splitting)
# Final number of rows: 76695
# Invalid entries removed (NA or empty): 0
# Duplicates removed: 0
# Total rows removed during processing: 0

# %%
od_exploded_Language = clean_and_split_forms(
    df=od_exploded_Concept, 
    column_name='Concept', 
    delimiters='default', 
    split_on_delimiters=False,
    verbose=True, 
    export_excel=False,                # Can take some time exporting to Excel
    filename='data_processing_results' # Will only be used when export_excel=True
)

#od_exploded_Language # Uncomment to view
# Out:
# Original number of rows: 76695
# Mode: Cleaning only (no delimiter splitting)
# Final number of rows: 76695
# Invalid entries removed (NA or empty): 0
# Duplicates removed: 0
# Total rows removed during processing: 0

# %% [markdown]
# In 3 lines above, we have done the ff.:
# - In the 'form' column, we have separated 2 or more words for 1 concept in separate rows
# - Removed duplicated rows, NAs or white spaces (the latter 2 are rarely run, which may mainly occur when 'Word' data is 'Word1, ' or ', Word2' and other
# - Exported the results
# - Store in 'od_exploded' variable
#
# The exploded data also has been applied with the ff. actions:
# - Replaces multiple consecutive spaces with single spaces
# - Removes tab characters (\t)
# - Removes newline characters (\n)
# - Removes carriage return characters (\r)
# - Removes non-breaking spaces (\xa0)
#
# The above were actually observations when the 'get_bad_characters' function was run PRIOR to data cleaning.
#
# The value in 'Total rows removed during processing' is what it says.
#
# For lines 2-3 above, we're just clearing any tabs, new lines, etc.

# %% [markdown]
# # Replace Characters to be IPA-ready

# %%
# Make a copy of exploded data
od_cleaned = od_exploded_Language.copy() # od_exploded_Language is used since there were times when there were tabs or newline in concepts and languages. od_exploded_Language is the latest cleaner data

# Define languages that require special glottal stop placement
special_placements_glottal_stops_languages = ['Abui_Bunggeta', 'Abui_Kilakawada', 'Abui_Mobyetang', 'Abui_Pelman'] 

# Group characters by their replacement values
replacement_groups = {
    '.': [' ', '–', '-'],                                             # Spaces and dashes to dots
    '': ['=', '?', '\\', '…', '!', '̃', '̇', '̝', '̪'],                   # Characters to remove 
    'ʔ': ['´', "'", '’', '´', '‘'],                                   # Quote variants to glottal stop
    'a': ['à', 'â', 'ᵄ'],                                             # A variants to a
    'e': ['ė', 'ѐ', 'è', 'é', 'ẽ', 'ĕ', 'ê', 'ə', 'ɛ', 'ḗ'],          # E variants to e
    'i': ['ì', 'í', 'î', 'ᵎ'],                                        # I variants to i
    'o': ['ò', 'ó', 'ό', 'ô', 'ö', 'ō', 'ŏ', 'ɔ', 'ɔ̝', 'ṑ', 'ṓ'],     # O variants to o
    'u': ['ù', 'ú', 'û'],                                             # U variants to u
    'n': ['ǹ', 'n̪', 'ň'],                                             # Single phonetic replacement
    'ɲ': ['ñ'],
    'aa': ['a:'],
    #'ee': ['e:'], # This is non-existent in the data
    'ii': ['i:'],
    'oo': ['oː'],
    'uu': ['u:'],
    'c': ['tʃ'],
    'j': ['dʒ'],
    'g': ['ɡ']
}

# Special handling for glottal stops in specific languages
# Replace single quote at the beginning of words with glottal stop for special languages
mask = od_cleaned['Language'].isin(special_placements_glottal_stops_languages)
od_cleaned.loc[mask, 'Word'] = od_cleaned.loc[mask, 'Word'].str.replace(r"^'", 'ʔ', regex=True)

# Remove all characters inside '()' and themselves
od_cleaned['Word'] = od_cleaned['Word'].str.replace(r'\(.*?\)', '', regex=True)

# Data with no parenthesis (this is specifically made for the summary of bad symbols, nothing else this is to be used)
od_cleaned_no_parenthesis = od_cleaned.copy()

# Remove ' and ' ONLY if they are the 1st character (the stress)
od_cleaned['Word'] = od_cleaned['Word'].str.replace(r'^[\'\u2019]', '', regex=True)

# Apply grouped replacements
for replacement, chars_to_replace in replacement_groups.items():
    for char in chars_to_replace:
        od_cleaned['Word'] = od_cleaned['Word'].str.replace(char, replacement, regex=False)

# Apply regex operations and case conversion
od_cleaned['Word'] = (od_cleaned['Word']
#              .str.lower()
#              # .str.replace(r'[\d]+', '', regex=True) # Replace numbers with empty string
              .str.replace(r'[\s]+', '.', regex=True)) # Replace spaces/tabs with period

# Filter out empty strings and single dots
od_cleaned = od_cleaned[(od_cleaned['Word'] != '') & (od_cleaned['Word'] != '.')]

# Replace space/s in 'Language' and 'Concept' columns with underscore '_'
od_cleaned['Language'] = [re.sub(r"\s+", '_', x) for x in od_cleaned['Language']]
#od_cleaned['Concept']  = [re.sub(r"\s+", '_', x) for x in od_cleaned['Concept']]

# %% [markdown]
# In the code above, we're on data cleaning. Specifically, making our wordlists consistent across all languages. We've replaces spaces with periods, removed special characters we know aren't necessary, uniformed glottal stops, uniformed variants of several vowels, and so on. We've also removed characters inside '()'.

# %%
# Count the occurrences of each language
language_counts = od_cleaned['Language'].value_counts()

# Create a bar plot of the language counts
plt.figure(figsize=(20, 8)) # Set the figure size for better readability
language_counts.plot.bar(color='steelblue')

# Add labels and title
plt.title('Number of Concepts (with Forms) per Language')
plt.xlabel(f'Language (n = {len(language_counts)})')
plt.ylabel('Number of Concepts')
plt.xticks(rotation=90, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from being cut off

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'concepts_per_language.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

# Display the plot
plt.show()

# Print the language counts (optional)
print("\nLanguage Counts:")
print(language_counts)
# Out:
# Language Counts:
# Language
# Kankana_ey      1732
# Bulus           1694
# Cuyunon         1414
# Bicolano        1370
# Ilognon         1315
#                 ...
# Mauta            229
# Sangil           200
# Bali_Aga         197
# Kupang_Malay     142
# Sabu_Seba        100
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# # Bad symbols after data cleaning
# If there are still characters which are not IPA-friendly, edit the 'replacement_groups' in the 'Replace Characters to be IPA-ready and remove characters inside '()'' section above.

# %%
# Function to Get Characters that are not from 'a' through 'z' in the English alphabet
def get_bad_characters(df, column_name, good_symbols=None, good_symbols_new=None, 
                       normalize_spaces=True, remove_tabs=True, remove_newlines=True, 
                       remove_carriage_returns=True, remove_non_breaking_spaces=True):
    """
    Extracts unique non-alphabetic sequences (symbols) from a specified DataFrame column,
    and then removes any of these symbols that are found in the provided 'good_symbols' 
    and 'good_symbols_new' lists.
    
    Args:
        df (pd.DataFrame): The input pandas DataFrame.
        column_name (str): The name of the column to extract symbols from.
        good_symbols (list, optional): A list of symbols to exclude from the final result.
                                       Defaults to None, meaning no symbols are excluded.
        good_symbols_new (list, optional): An additional list of characters to exclude 
                                           from the final result. Defaults to None, 
                                           meaning no additional symbols are excluded.
        normalize_spaces (bool, optional): If True, replaces multiple consecutive spaces 
                                          with single spaces. Defaults to True.
        remove_tabs (bool, optional): If True, removes tab characters (\t). Defaults to True.
        remove_newlines (bool, optional): If True, removes newline characters (\n). Defaults to True.
        remove_carriage_returns (bool, optional): If True, removes carriage return characters (\r). 
                                                 Defaults to True.
        remove_non_breaking_spaces (bool, optional): If True, removes non-breaking spaces (\xa0). 
                                                     Defaults to True.
    
    Returns:
        list: A sorted list of unique symbols found in the column,
              excluding those specified in good_symbols and good_symbols_new.
    """
    if good_symbols is None:
        good_symbols = []
    if good_symbols_new is None:
        good_symbols_new = []
    
    # Combine both good symbol lists and ensure it's a set for efficient lookup
    all_good_symbols = set(good_symbols + good_symbols_new)
    
    # Use a set to store unique symbols found across all entries
    found_symbols = set()
    
    # Iterate through unique non-null values in the specified column
    # .astype(str) ensures all values are strings before applying regex
    for text in df[column_name].dropna().astype(str).unique():
        # Clean the text based on the provided parameters
        cleaned_text = text
        
        # Remove/replace whitespace characters based on parameters
        if remove_tabs:
            cleaned_text = cleaned_text.replace('\t', ' ')
        if remove_newlines:
            cleaned_text = cleaned_text.replace('\n', ' ')
        if remove_carriage_returns:
            cleaned_text = cleaned_text.replace('\r', ' ')
        if remove_non_breaking_spaces:
            cleaned_text = cleaned_text.replace('\xa0', ' ')
        
        # Normalize multiple spaces to single spaces
        if normalize_spaces:
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
        
        # Find all individual non-alphabetic characters
        # This will capture each symbol individually: '!', "'", '1', '2', '?' etc.
        # Example: 'bless\'12' -> ['\'', '1', '2']
        # Example: 'code!' -> ['!']
        # Example: 'hello world!' -> [' ', '!']
        # Note: If spaces are symbols you want to capture, this regex is good.
        # If spaces should be ignored, a different regex would be needed (e.g., [^a-zA-Z\s])
        non_alphabetic_matches = re.findall(r'[^a-zA-Z]', cleaned_text)
        for match in non_alphabetic_matches:
            found_symbols.add(match)
    
    # Filter out symbols that are in the all_good_symbols set
    result_symbols = [symbol for symbol in found_symbols if symbol not in all_good_symbols]
    
    # Return a sorted list for consistent output
    return sorted(result_symbols)

# %%
badsymbols = get_bad_characters(od_cleaned, 'Word', good_symbols_new=None)
badsymbols
# Out:
# ['.', 'ŋ', 'ɲ', 'ʔ']

# %% [markdown]
# After removing the characters we do not want, the above characters remain, which I hope are the only characters we deem good or necessary to move forward. Otherwise, we remove/replace such characters in the 'Replace Characters to be IPA-ready and remove characters inside '()'' section above.

# %% [markdown]
# ## Check Which Languages have Bad Symbols

# %%
# Function to Check Which Languages have Bad Symbols
def check_languages_with_bad_symbols(df, column='Word', symbols=None, languages="all", reportok=False, show=False, except_symbols=None):
    """
    Comprehensive analysis of symbol occurrences across multiple languages in a linguistic dataset.
    Purpose: Batch processing to check for multiple symbols across multiple languages,
    providing a complete overview of symbol distribution patterns in the dataset.
    Parameters:
    - df: Main DataFrame containing linguistic data
    - symbols: List of symbols/characters to search for (default: None, must be provided)
    - languages: Languages to check - "all" for all languages, or list of specific languages (default: "all")
    - reportok: Boolean flag to print "OK!" for languages with no matches (default: False)
    - show: Boolean flag to display actual forms containing symbols (default: False)
    - column: Column to search in (default: 'form', could be other columns)
    - except_symbols: List of symbols to exclude from the results (default: None)
    Returns: Nested dictionary {symbol: {language: count}} with occurrence counts
    Example usage: Batch check for problematic characters across all languages in a dataset,
    useful for data quality assessment, encoding issue detection, or linguistic pattern analysis.
    """
    # Step 1: Input validation and setup
    if symbols is None:
        raise ValueError("symbols parameter must be provided - cannot be None; must be a list")
    # Ensure symbols is a list for consistent processing
    if isinstance(symbols, str):
        symbols = [symbols]
    
    # Handle except_symbols parameter
    if except_symbols is not None:
        if isinstance(except_symbols, str):
            except_symbols = [except_symbols]
        # Filter out excluded symbols from the main symbols list
        symbols = [symbol for symbol in symbols if symbol not in except_symbols]
        if not symbols:
            print("Warning: All symbols were excluded. No symbols to check.")
            return {}
        print(f"Excluding {len(except_symbols)} symbol(s) from analysis: {except_symbols}")
    else:
        except_symbols = []
    
    # Step 2: Handle language selection efficiently
    if languages == "all":
        # Get unique languages once, sort for consistent output
        available_languages = sorted(df['Language'].dropna().unique())
        if len(available_languages) == 0:
            print("Warning: No languages found in 'Language' column")
            return {}
        print(f"Checking {len(symbols)} symbol(s) across {len(available_languages)} language(s)")
        languages = available_languages
    else:
        # FIX: Ensure languages is a list for consistent processing
        if isinstance(languages, str):
            languages = [languages]
        
        # Validate that requested languages exist in the dataset
        available_languages = set(df['Language'].dropna().unique())
        missing_languages = [lang for lang in languages if lang not in available_languages]
        if missing_languages:
            print(f"Warning: These languages not found in dataset: {missing_languages}")
            # Filter to only existing languages
            languages = [lang for lang in languages if lang in available_languages]
        if not languages:
            print("Error: No valid languages to check")
            return {}
    
    # Step 3: Initialize results structure
    # Using nested dictionary for efficient lookups and clear structure
    results = {}
    
    # Step 4: Process each symbol across all languages
    print("\n" + "="*50)
    print("SYMBOL ANALYSIS REPORT")
    print("="*50)
    
    for i, symbol in enumerate(symbols, 1):
        print(f"\n[{i}/{len(symbols)}] Checking symbol: '{symbol}'")
        print("-" * 30)
        
        # Initialize nested dictionary for this symbol
        results[symbol] = {}
        
        # Track summary statistics for this symbol
        total_occurrences = 0
        languages_with_symbol = 0
        
        # Step 5: Check each language for the current symbol (formerly checkpair logic)
        for language in languages:
            # Filter dataset to only rows matching the specified language
            lang_data = df[df['Language'] == language].copy()
            
            # Early return if no data for this language
            if lang_data.empty:
                if reportok:
                    print(f"{language}: No data found for this language")
                results[symbol][language] = 0
                continue # Move to the next language
            
            # Handle missing values - only search in non-null entries
            search_column = lang_data[column].dropna()
            if search_column.empty:
                if reportok:
                    print(f"{language}: No valid data in '{column}' column")
                results[symbol][language] = 0
                continue # Move to the next language
            
            # Search for the symbol in the specified column
            contains_symbol = search_column.str.contains(symbol, regex=False, na=False)
            
            # Count matches
            count = contains_symbol.sum()
            
            # Store results
            results[symbol][language] = count
            
            # Report results for the current language-symbol pair
            if count > 0:
                print(f"{language} contains {count} occurrence(s) of '{symbol}' symbol")
                # Optional detailed display of matching forms
                if show:
                    matching_indices = search_column[contains_symbol].index
                    print("Matching entries:")
                    # Ensure 'Concept' column exists before trying to access it
                    if 'Concept' in lang_data.columns:
                        for idx in matching_indices:
                            form = lang_data.loc[idx, 'form']
                            Concept = lang_data.loc[idx, 'Concept']
                            print(f"  • {form} - Concept: {Concept}")
                    else:
                        for idx in matching_indices:
                            form = lang_data.loc[idx, 'form']
                            print(f"  • {form}")
            elif reportok: # Report when no matches found (if requested)
                print(f"{language}: OK! (no '{symbol}' found)")
            
            # Update summary statistics for the current symbol
            total_occurrences += count
            if count > 0:
                languages_with_symbol += 1
        
        # Step 6: Print summary for this symbol
        #print(f"\nSummary for '{symbol}':")
        #print(f"  • Total occurrences: {total_occurrences}")
        #print(f"  • Languages containing symbol: {languages_with_symbol}/{len(languages)}")
        #if languages_with_symbol > 0:
        #    # Show which languages have the symbol
        #    affected_languages = [lang for lang, count in results[symbol].items() if count > 0]
        #    print(f"  • Affected languages: {', '.join(affected_languages[:5])}" +
        #          (f" (and {len(affected_languages)-5} more)" if len(affected_languages) > 5 else ""))
    
    # Step 8: Return structured results for further analysis
    return results

# %%
# Create a list of symbols that will not be included in the summary
except_symbols=['.', 'ʔ', 'ŋ', 'ɲ']

# %%
results = check_languages_with_bad_symbols(od_cleaned, column='Word', symbols=badsymbols, except_symbols=except_symbols, languages="all", reportok=False, show=False)
# Out:
# Warning: All symbols were excluded. No symbols to check.

# %% [markdown]
# # View what these are specifically

# %%
# Function to View Which Language has the Bad Symbols
def check_linguistic_data(data_df, symbols=None, languages="all", column_to_check='Word', 
                         is_regex=False, except_symbols=None, display_results=True, 
                         export_excel_path=None):
    """
    Checks for specified symbols/patterns in requested languages and provides options
    for console display and Excel export.
    
    Args:
        data_df (pd.DataFrame): The input DataFrame containing linguistic data.
        symbols (list): A list of symbols or regex patterns to check for.
                       Defaults to the global `badsymbols` list if None.
        languages (list or "all"): A list of language doculects to check.
                                  "all" checks all unique languages in the DataFrame.
        column_to_check (str): The column in the DataFrame to search ('Word' or 'Concept').
        is_regex (bool): If True, treats `symbols` as regex patterns.
        except_symbols (list): List of symbols to exclude from the analysis, even if they
                              appear in the `symbols` parameter.
        display_results (bool): If True, prints results to the console in a readable format.
        export_excel_path (str): If provided, the directory to export results as an Excel file.
                                A timestamped filename will be generated. E.g., 'output_reports'.
    
    Returns:
        pd.DataFrame: A DataFrame containing all found issues. Returns an empty DataFrame
                     if no issues are found.
    """
    # Handle default symbols
    if symbols is None:
        symbols = badsymbols  # Use the globally defined list if no specific list is provided
    
    # Filter out excluded symbols
    if except_symbols:
        symbols = [sym for sym in symbols if sym not in except_symbols]
        if not symbols:
            print("All symbols have been excluded. No analysis to perform.")
            return pd.DataFrame()
    
    # Handle languages
    if languages == "all":
        languages = list(data_df['Language'].unique())
    
    print(f"Initiating check for symbols/patterns in the '{column_to_check}' column...")
    
    all_findings = []
    
    # Process all combinations efficiently
    for symbol in symbols:
        for language in languages:
            # Filter data for current language
            lang_df = data_df[data_df['Language'] == language]
            
            if column_to_check not in lang_df.columns:
                print(f"Warning: Column '{column_to_check}' not found for language '{language}'. Skipping.")
                continue
            
            # Find matches using vectorized operations
            matches = lang_df[column_to_check].astype(str).str.contains(symbol, regex=is_regex, na=False)
            
            if matches.any():
                matched_rows = lang_df[matches]
                # Create findings for all matches at once
                for index, row in matched_rows.iterrows():
                    all_findings.append({
                        'Language': language,
                        'Symbol_or_Pattern': symbol,
                        'Column': column_to_check,
                        'Word': row.get('Word'),
                        'Concept': row.get('Concept'),
                        'ID': index
                    })
    
    if not all_findings:
        print("No issues found based on the specified criteria.")
        return pd.DataFrame()
    
    results_df = pd.DataFrame(all_findings)
    
    # Display results to console if requested
    if display_results:
        print("\n--- Detailed Results Summary ---")
        # Group by language and symbol for clearer display
        for (lang, sym), group_df in results_df.groupby(['Language', 'Symbol_or_Pattern']):
            print(f"\nLanguage: {lang}, Symbol/Pattern: '{sym}' (Column: '{group_df['Column'].iloc[0]}')")
            for _, row in group_df.iterrows():
                word_info = f"Word: '{row['Word']}'" if pd.notna(row['Word']) else "Word: N/A"
                concept_info = f"Concept: '{row['Concept']}'" if pd.notna(row['Concept']) else "Concept: N/A"
                id_info = f"ID: {row['ID']}" if pd.notna(row['ID']) else "ID: N/A"
                
                details = ", ".join(filter(None, [word_info, concept_info, id_info]))
                print(f"  - {details}")
    
    # Export to Excel if path is provided
    if export_excel_path:
        if not os.path.exists(export_excel_path):
            os.makedirs(export_excel_path)
            print(f"\nCreated output directory: {os.path.abspath(export_excel_path)}")
        
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"Linguistic_Check_Results_{timestamp}.xlsx"
        full_path = os.path.join(export_excel_path, filename)
        
        try:
            results_df.to_excel(full_path, index=False)
            print(f"Results successfully exported to: {os.path.abspath(full_path)}")
        except Exception as e:
            print(f"\nError exporting results to Excel: {e}")
    
    return results_df

# %%
results = check_linguistic_data(od_cleaned, symbols=badsymbols, except_symbols=except_symbols)
# Out:
# All symbols have been excluded. No analysis to perform.

# %% [markdown]
# If there are still bad symbols, go back to 'Replace Characters to be IPA-ready' section and add the bad symbols that needed attention.

# %% [markdown]
# # Bad Symbols Summary
# except for forms with ' ' (space) since there are a lot of them

# %%
really_badsymbols = [] # All values from 'replacement_groups' dictionary
for value_list in replacement_groups.values():
    really_badsymbols.extend(value_list)

uncleaned = od_exploded.copy()                                   # Make a copy of the uncleaned data
except_symbols2 = except_symbols + [' ']                         # Add the space ' '  since it's making the summmary very long

bad_results = check_linguistic_data(uncleaned, symbols=really_badsymbols, except_symbols=except_symbols2)

# Export to Excel
# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = "OCSEAN_Languages_with_Bad_Symbols.xlsx"
output_file_path = os.path.join(results_folder_name, file_name)

try:
    bad_results.to_excel(output_file_path, index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")
# Out:
# Initiating check for symbols/patterns in the 'Word' column...
#
# --- Detailed Results Summary ---
#
# Language: Abui_Bunggeta, Symbol/Pattern: ''' (Column: 'Word')
#   - Word: ''uya', Concept: 'moon', ID: 1
#   - Word: ''adiiy', Concept: 'sky', ID: 3
#   - Word: ''agalai', Concept: 'thunder', ID: 18
#   - Word: ''anai', Concept: 'land, earth, soil', ID: 38
#   - Word: ''anai maau', Concept: 'clay', ID: 43
#   - Word: ''ara wasing', Concept: 'fire', ID: 47
#   - Word: ''ara', Concept: 'fire', ID: 48
#   - Word: ''ara tika', Concept: 'smoke', ID: 49
#   - Word: ''aruui', Concept: 'ash', ID: 50
#   - Word: ''ara', Concept: 'firewood', ID: 51
#   - Word: ''ara taqata', Concept: 'firewood', ID: 52
#   - Word: ''aquuni', Concept: 'night', ID: 66
#   - Word: ''afee', Concept: 'yesterday', ID: 71
#   - Word: ''ariiy', Concept: 'tomorrow', ID: 74
#   - Word: ''ooqi ariiy', Concept: 'day after tomorrow', ID: 76
#   - Word: ''ariiy pee', Concept: 'twilight, dawn', ID: 77
#   - Word: ''afeeng', Concept: 'village', ID: 82
#   - Word: ''uti muni', Concept: 'wet rice field', ID: 83
#   - Word: ''utiy', Concept: 'garden', ID: 85
#   - Word: ''uti', Concept: 'garden', ID: 86
#   - Word: ''e kidiing', Concept: 'boat', ID: 90
#   - Word: ''e'', Concept: 'boat', ID: 91
#   - Word: ''aremang fala', Concept: 'traditional house', ID: 120
#   - Word: ''awenggaau', Concept: 'door', ID: 129
#   - Word: ''aai', Concept: 'root', ID: 160
#   - Word: ''ayaqi kai wee', Concept: 'rice plant', ID: 163
#   - Word: ''ayaq', Concept: 'rice plant', ID: 164
#   - Word: ''ayaq', Concept: 'uncooked rice', ID: 168
#   - Word: ''ayaq biikang', Concept: 'uncooked rice', ID: 169
#   - Word: ''ayaq nagani', Concept: 'grain', ID: 175
#   - Word: ''ayaq', Concept: 'grain', ID: 176
#   - Word: ''ayaq qai gee', Concept: 'grain', ID: 177
#   - Word: ''ayaq taaqa', Concept: 'plant (rice)', ID: 180
#   - Word: ''awaai', Concept: 'lime', ID: 184
#   - Word: ''ahoo', Concept: 'taro', ID: 190
#   - Word: 'fa'', Concept: 'sugarcane', ID: 196
#   - Word: ''aaqal iyeri', Concept: 'lontar palm', ID: 201
#   - Word: 'sefaa'', Concept: 'gebang palm', ID: 202
#   - Word: 'sefa'', Concept: 'gebang palm', ID: 203
#   - Word: 'nau 'iyeri', Concept: 'sugar palm', ID: 204
#   - Word: ''upi', Concept: 'fruit', ID: 207
#   - Word: ''ike', Concept: 'vomit', ID: 2785
#   - Word: 'hapaa'da', Concept: 'slap', ID: 2791
#   - Word: ''amakaang fayeeng', Concept: 'kill', ID: 2802
#   - Word: 'heet'iya', Concept: 'bury', ID: 2807
#   - Word: 'heed'iya', Concept: 'bury', ID: 2808
#   - Word: 'dalii'da', Concept: 'turn', ID: 2817
#   - Word: 'wiiy hatoo' mia', Concept: 'pregnant', ID: 2820
#   - Word: ''ahia', Concept: 'choose', ID: 2821
#   - Word: 'we'aria', Concept: 'squeeze', ID: 2823
#   - Word: ''ayaq tapee', Concept: 'pound', ID: 2838
#   - Word: 'hale'da', Concept: 'count', ID: 2843
#   - Word: ''ayoki', Concept: 'two', ID: 2845
#   - Word: 'sen'ayoki', Concept: 'seven', ID: 2850
#   - Word: 'karnu' waal 'ayoki', Concept: 'twelve', ID: 2855
#   - Word: 'karnu' waal sua', Concept: 'thirteen', ID: 2856
#   - Word: 'karnu' waal buti', Concept: 'fourteen', ID: 2857
#   - Word: 'karnu' waal seting', Concept: 'fifteen', ID: 2858
#   - Word: 'karnu' waal talaama', Concept: 'sixteen', ID: 2859
#   - Word: 'karnu' waal sen'ayoki', Concept: 'seventeen', ID: 2860
#   - Word: 'karnu' waal seting sua', Concept: 'eighteen', ID: 2861
#   - Word: 'karnu' waal seting buti', Concept: 'nineteen', ID: 2862
#   - Word: 'kar'ayoki', Concept: 'twenty', ID: 2863
#   - Word: 'kar'ayo' waal nuki', Concept: 'twenty one', ID: 2864
#   - Word: 'kar'ayo' waal 'ayoki', Concept: 'twenty two', ID: 2865
#   - Word: 'kar'ayo' waal sua', Concept: 'twenty three', ID: 2866
#   - Word: 'kar'ayo' waal buti', Concept: 'twenty four', ID: 2867
#   - Word: 'kar'ayo' waal seting', Concept: 'twenty five', ID: 2868
#   - Word: 'karsen 'ayoki', Concept: 'seventy', ID: 2873
#   - Word: ''aisaaha nuki', Concept: 'one hundred', ID: 2876
#   - Word: ''aisaaha nuki kar'ayo' waal sua', Concept: 'one hundred and twenty three', ID: 2877
#   - Word: ''aisaaha 'ayoki', Concept: 'two hundred', ID: 2878
#   - Word: 'riifi 'aisaaha nuki', Concept: 'one hundred thousand', ID: 2879
#   - Word: ''ayiini', Concept: 'necklace', ID: 2897
#   - Word: 'dataang mi hiyekai taahi ya 'akuuike', Concept: 'bless', ID: 2908
#   - Word: 'ne'adua', Concept: 'god', ID: 2909
#   - Word: ''aisaala', Concept: 'god', ID: 2910
#   - Word: ''akuuike', Concept: 'pray', ID: 2911
#   - Word: ''akui' toofa', Concept: 'church', ID: 2912
#   - Word: 'kai 'akan he'akui' toofa', Concept: 'mosque', ID: 2914
#   - Word: 'ho'ahanra', Concept: 'curse', ID: 2915
#   - Word: 'tada'akuike hefoka', Concept: 'priest (protestant)', ID: 2916
#   - Word: 'tada'akui' hefoka', Concept: 'priest (protestant)', ID: 2917
#   - Word: 'tada'akui' hefoka', Concept: 'priest (catholic)', ID: 2919
#   - Word: 'kai 'akan hoo'akuike', Concept: 'imam', ID: 2921
#   - Word: 'doro ta'at', Concept: 'thirsty', ID: 3180
#   - Word: 'tama'any', Concept: 'rotten', ID: 3187
#   - Word: 'la'an', Concept: 'black', ID: 3189
#   - Word: 'ba'oy', Concept: 'yellow', ID: 3190
#   - Word: 'ho'o', Concept: 'this', ID: 3194
#   - Word: 'ho'', Concept: 'that', ID: 3195
#   - Word: 'ho'o mi', Concept: 'here', ID: 3196
#   - Word: 'ho' mi', Concept: 'there', ID: 3197
#   - Word: 'fed po'', Concept: 'east', ID: 3200
#   - Word: 'er'alo', Concept: 'twenty', ID: 3218
#   - Word: 'te'eng', Concept: 'run', ID: 3250
#   - Word: 'ho'', Concept: 'come', ID: 3259
#   - Word: 'afo'oy', Concept: 'pregnant', ID: 3260
#   - Word: 'ha'aiy', Concept: 'not', ID: 3261
#   - Word: 'taro'ni', Concept: 'how?', ID: 3266
#   - Word: 'taro'ni', Concept: 'why?', ID: 3267
#
# Language: Adang, Symbol/Pattern: 'ᵄ' (Column: 'Word')
#   - Word: 'ᵄh', Concept: 'excrement', ID: 3038
#   - Word: 'ᵄ', Concept: '2sg (informal)', ID: 3067
#   - Word: 'ᵄri', Concept: '2sg (informal)', ID: 3068
#
# Language: Adang, Symbol/Pattern: 'ᵎ' (Column: 'Word')
#   - Word: 'ᵎri', Concept: '2pl', ID: 3074
#
# Language: Adang, Symbol/Pattern: 'ḗ' (Column: 'Word')
#   - Word: 'fḗl', Concept: 'ear', ID: 2999
#   - Word: 'afḗl', Concept: 'ear', ID: 3000
#   - Word: 'tenang ḗl', Concept: 'friend', ID: 3063
#   - Word: 'bḗng', Concept: 'body hair', ID: 3081
#
# Language: Adang, Symbol/Pattern: 'ṑ' (Column: 'Word')
#   - Word: 'tṑr', Concept: 'shoulder', ID: 3009
#   - Word: 'notṑr', Concept: 'shoulder', ID: 3010
#   - Word: 'pṑt', Concept: 'thigh', ID: 3020
#   - Word: 'apṑt', Concept: 'thigh', ID: 3021
#   - Word: 'napṑt', Concept: 'thigh', ID: 3022
#   - Word: 'ṑm', Concept: 'liver', ID: 3034
#
# Language: Adang, Symbol/Pattern: 'ṓ' (Column: 'Word')
#   - Word: 'ṓiny', Concept: 'head louse', ID: 3083
#
# Language: Agta, Symbol/Pattern: '-' (Column: 'Word')
#   - Word: 'pagu-yu', Concept: 'cliff', ID: 3274
#   - Word: 'lumba-lumba', Concept: 'dolphin', ID: 3442
#   - Word: 'kalibong-bong', Concept: 'butterfly', ID: 3483
#   - Word: 'luyang-dilaw', Concept: 'turmeric', ID: 3834
#   - Word: 'o-ong', Concept: 'mushroom', ID: 3835
#   - Word: 'labing-apat', Concept: 'fourteen', ID: 4038
#   - Word: 'tag-uden', Concept: 'rainy season', ID: 4090
#   - Word: 'tag-araw', Concept: 'dry season', ID: 4091
#   - Word: 'bureket-ket', Concept: 'tickle', ID: 4149
#
# Language: Agusan_Manobo, Symbol/Pattern: ''' (Column: 'Word')
#   - Word: 'pulu'', Concept: 'island', ID: 4257
#   - Word: 'iya'an', Concept: 'aunt', ID: 4369
#   - Word: 'dila'an', Concept: 'lick', ID: 4547
#   - Word: 'ginhawa'an', Concept: 'breathe', ID: 4619
#   - Word: 'ug-u'ugpa', Concept: 'live, be alive, living', ID: 4653
#   - Word: 'do'og', Concept: 'hit (drum)', ID: 4950
#   - Word: 'hasa'an', Concept: 'whetstone', ID: 4960
#   - Word: 'binaya'an', Concept: 'broken, not working or out of order', ID: 4963
#   - Word: 'ta'as', Concept: 'lift up', ID: 4995
#   - Word: 'ta'as sang suba', Concept: 'upriver', ID: 5091
#   - Word: 'ta'as', Concept: 'tall', ID: 5116
#   - Word: 'ta'as', Concept: 'high', ID: 5117
#   - Word: 'ta'ang', Concept: 'narrow', ID: 5138
#   - Word: 'napulo'g usik', Concept: 'eleven', ID: 5162
#   - Word: 'napulo'g duha', Concept: 'twelve', ID: 5163
#   - Word: 'napulo'g tolo', Concept: 'thirteen', ID: 5164
#   - Word: 'napulo'g upat', Concept: 'fourteen', ID: 5165
#   - Word: 'napulo'g lima', Concept: 'fifteen', ID: 5166
#   - Word: 'napulo'g unom', Concept: 'sixteen', ID: 5167
#   - Word: 'napulo'g pito', Concept: 'seventeen', ID: 5168
#   - Word: 'napulo'g walo', Concept: 'eighteen', ID: 5169
#   - Word: 'napulo'g siyam', Concept: 'nineteen', ID: 5170
#   - Word: 'kawha'an', Concept: 'twenty', ID: 5171
#   - Word: 'kawha'an nga usik', Concept: 'twenty one', ID: 5172
#   - Word: 'kawha'an nga duha', Concept: 'twenty two', ID: 5173
#   - Word: 'kawha'an nga tolo', Concept: 'twenty three', ID: 5174
#   - Word: 'kawha'an nga upat', Concept: 'twenty four', ID: 5175
#   - Word: 'kawha'an nga lima', Concept: 'twenty five', ID: 5176
#   - Word: 'kalima'an', Concept: 'fifty', ID: 5179
#   - Word: 'kawhana'an', Concept: 'sixty', ID: 5180
#   - Word: 'kawha'ana'an', Concept: 'eighty', ID: 5182
#   - Word: 'isang gatus ug kawha'an nga usik', Concept: 'one hundred and twenty three', ID: 5185
#   - Word: 'tungang gabi'i', Concept: 'midnight', ID: 5219
#   - Word: 'ma'anghang', Concept: 'spicy', ID: 5243
#   - Word: 'ma'asim', Concept: 'sour', ID: 5247
#   - Word: 'ma'angit', Concept: 'acrid, sharp flavor', ID: 5248
#   - Word: 'tan-aw sa ita'as', Concept: 'look upward', ID: 5258
#   - Word: 'ugsila'ab', Concept: 'blaze, shine', ID: 5263
#   - Word: 'ma'agkap', Concept: 'light (weight)', ID: 5288
#   - Word: 'ug-kama'an', Concept: 'know something', ID: 5353
#   - Word: 'ug-ka'amo', Concept: 'know how do something', ID: 5357
#   - Word: 'iyang na'an kan', Concept: 'because', ID: 5375
#   - Word: 'o'o', Concept: 'yes', ID: 5379
#   - Word: 'na'an', Concept: 'what-you-may-call-it (hesitation word)', ID: 5383
#   - Word: 'a'angod', Concept: 'same', ID: 5396
#   - Word: 'paga'as', Concept: 'hoarse', ID: 5399
#   - Word: 'ug-sa'ad', Concept: 'promise', ID: 5418
#   - Word: 'ug-sugo'on', Concept: 'order', ID: 5437
#   - Word: 'ka'away', Concept: 'enemy', ID: 5442
#   - Word: 'bala'an', Concept: 'holy', ID: 5489
#
# Language: Agusan_Manobo, Symbol/Pattern: '-' (Column: 'Word')
#   - Word: 'talan-awon', Concept: 'plain', ID: 4254
#   - Word: 'bo-ugan', Concept: 'stream', ID: 4279
#   - Word: 'bo-ugan', Concept: 'spring', ID: 4285
#   - Word: 'bala-as', Concept: 'swamp, wetland', ID: 4288
#   - Word: 'ma-nok', Concept: 'chicken', ID: 4405
#   - Word: 'bu-yang', Concept: 'cockfight', ID: 4408
#   - Word: 'manok-manok', Concept: 'bird', ID: 4411
#   - Word: 'ba-nog', Concept: 'hawk', ID: 4414
#   - Word: 'ka-bog', Concept: 'bat', ID: 4420
#   - Word: 'ka-bog', Concept: 'flying fox, fruit bat', ID: 4422
#   - Word: 'bitu-on to dagat', Concept: 'starfish', ID: 4432
#   - Word: 'ka-gang', Concept: 'crab', ID: 4443
#   - Word: 'ug-ukapan', Concept: 'sea cucumber', ID: 4447
#   - Word: 'a-mo', Concept: 'monkey', ID: 4452
#   - Word: 'panuk-an', Concept: 'crush lice with one's fingernail', ID: 4457
#   - Word: 'hi-nop', Concept: 'chicken louse', ID: 4458
#   - Word: 'i-pus', Concept: 'cockroach', ID: 4464
#   - Word: 'salipit-sipit', Concept: 'scorpion', ID: 4465
#   - Word: 'yawa-yawa', Concept: 'spider', ID: 4468
#   - Word: 'yawa-yawa', Concept: 'spider web, cobweb', ID: 4469
#   - Word: 'ug-ungot', Concept: 'sting', ID: 4470
#   - Word: 'ka-yog', Concept: 'earthworm', ID: 4478
#   - Word: 'ba-tud', Concept: 'edible grub', ID: 4482
#   - Word: 'kaba-kaba', Concept: 'butterfly', ID: 4486
#   - Word: 'ta-sik', Concept: 'grasshopper', ID: 4487
#   - Word: 'ta-sik', Concept: 'praying mantis', ID: 4490
#   - Word: 'bao-u', Concept: 'turtle', ID: 4497
#   - Word: 'bao-u', Concept: 'tortoise', ID: 4498
#   - Word: 'ya-wa', Concept: 'body', ID: 4499
#   - Word: 'i-la', Concept: 'mole, birthmark', ID: 4501
#   - Word: 'ko-ko', Concept: 'chin', ID: 4526
#   - Word: 'utaw-utaw', Concept: 'eyeball', ID: 4532
#   - Word: 'utow-utow', Concept: 'pupil', ID: 4533
#   - Word: 'be-las', Concept: 'mote', ID: 4534
#   - Word: 'bag-ang', Concept: 'molar tooth', ID: 4551
#   - Word: 'ug-giok', Concept: 'footprint', ID: 4589
#   - Word: 'mo-tudyo to kubong', Concept: 'toe', ID: 4591
#   - Word: 'tinu-e', Concept: 'guts', ID: 4607
#   - Word: 'bat-ang', Concept: 'hip', ID: 4609
#   - Word: 'si-ukon', Concept: 'hiccough', ID: 4622
#   - Word: 'ug-uromon', Concept: 'nightmare', ID: 4636
#   - Word: 'ug-buyat', Concept: 'wake up', ID: 4639
#   - Word: 'ug-buyat', Concept: 'wake someone up', ID: 4640
#   - Word: 'ug-ihì', Concept: 'urinate', ID: 4644
#   - Word: 'ug-indos', Concept: 'defecate', ID: 4645
#   - Word: 'ug-buyat', Concept: 'bathe', ID: 4649
#   - Word: 'ug-u'ugpa', Concept: 'live, be alive, living', ID: 4653
#   - Word: 'masa-kit', Concept: 'sick', ID: 4664
#   - Word: 'suga-suga', Concept: 'ringworm', ID: 4679
#   - Word: 'tabeg-tabeg', Concept: 'naked, bare', ID: 4696
#   - Word: 'sop-sop', Concept: 'suck, breastfeed', ID: 4713
#   - Word: 'so-so', Concept: 'suck, breastfeed', ID: 4714
#   - Word: 'sop-sop', Concept: 'suck', ID: 4715
#   - Word: 'sep-sep', Concept: 'sip, slurp', ID: 4716
#   - Word: 'sing-sing', Concept: 'ring (for finger)', ID: 4776
#   - Word: 'uy-an', Concept: 'pillow', ID: 4807
#   - Word: 'gas-ow', Concept: 'rafter', ID: 4817
#   - Word: 'tang-tang', Concept: 'lime container', ID: 4875
#   - Word: 'ka-ang', Concept: 'sweetsop', ID: 4918
#   - Word: 'kau-ang', Concept: 'rough bamboo, giant bamboo (dendrocalamus asper)', ID: 4928
#   - Word: 'yuy-a', Concept: 'ginger', ID: 4933
#   - Word: 'ga-ut', Concept: 'pull', ID: 4972
#   - Word: 'ga-hidit', Concept: 'hang up', ID: 4973
#   - Word: 'puy-aw', Concept: 'blow', ID: 5007
#   - Word: 'tan-aw', Concept: 'look for, seek', ID: 5061
#   - Word: 'tig-on', Concept: 'straight', ID: 5145
#   - Word: 'bag-o', Concept: 'new', ID: 5200
#   - Word: 'tig-ulo', Concept: 'old (thing)', ID: 5202
#   - Word: 'tig-ukay', Concept: 'old (person)', ID: 5203
#   - Word: 'kagabi-i', Concept: 'last night', ID: 5230
# ...
#   - Word: 'sip-on', Concept: 'snot, mucus', ID: 74635
#   - Word: 'ba-ba', Concept: 'mouth', ID: 74636
#   - Word: 'ngala-ngala', Concept: 'palate', ID: 74638
#   - Word: 'bag-ang', Concept: 'molar tooth', ID: 74645
#   - Word: 'bot-ol', Concept: 'adam's apple', ID: 74652
#   - Word: 'kum-kum', Concept: 'fist', ID: 74662
#   - Word: 'lokon-lokon', Concept: 'back of the knee', ID: 74678
#   - Word: 'bol-ong', Concept: 'heel', ID: 74679
#   - Word: 'ti-agi', Concept: 'footprint', ID: 74681
#   - Word: 'buko-boko', Concept: 'ankle', ID: 74682
#   - Word: 'balat-ang', Concept: 'hip', ID: 74701
#   - Word: 'dog-ay', Concept: 'burp, belch', ID: 74715
#   - Word: 'nag-inop', Concept: 'dream', ID: 74726
#   - Word: 'bango-ngot', Concept: 'nightmare', ID: 74727
#   - Word: 'pag-ihi', Concept: 'urinate', ID: 74734
#   - Word: 'magsulob-on', Concept: 'mourn, be in mourning', ID: 74745
#   - Word: 'bun-i', Concept: 'ringworm', ID: 74762
#   - Word: 'ka-un', Concept: 'eat', ID: 74780
#   - Word: 'kakan-on', Concept: 'food', ID: 74781
#   - Word: 'sud-an', Concept: 'viand', ID: 74790
#   - Word: 'nag-aram', Concept: 'loom', ID: 74842
#   - Word: 'pag-surod', Concept: 'comb for lice with a fine tooth comb', ID: 74856
#   - Word: 'kapuy-an', Concept: 'shelter', ID: 74861
#   - Word: 'sag-ob', Concept: 'fetch water', ID: 74887
#   - Word: 'pag-igok', Concept: 'thresh', ID: 74898
#   - Word: 'tabak-anan', Concept: 'tobacco container', ID: 74940
#   - Word: 'talong-talongan', Concept: 'black nightshade', ID: 74955
#   - Word: 'lum-od nga lubi', Concept: 'old coconut', ID: 74957
#   - Word: 'luy-a', Concept: 'ginger', ID: 74996
#   - Word: 'ipit-ipit', Concept: 'string together', ID: 75008
#   - Word: 'buak-buak', Concept: 'broken in pieces', ID: 75027
#   - Word: 'i-alsa', Concept: 'lift up', ID: 75057
#   - Word: 'mag-agos', Concept: 'flow', ID: 75064
#   - Word: 'mag-uyog', Concept: 'crawl', ID: 75070
#   - Word: 'dap-ayan', Concept: 'outrigger', ID: 75106
#   - Word: 'mawad-an sa negosyo', Concept: 'lose in business', ID: 75138
#   - Word: 'sa tunga-tunga', Concept: 'in the middle of', ID: 75181
#   - Word: 'tulo ka-kawhaan', Concept: 'thirty', ID: 75238
#   - Word: 'upat ka-kawhaan', Concept: 'forty', ID: 75239
#   - Word: 'lima ka-kawhaan', Concept: 'fifty', ID: 75240
#   - Word: 'unom ka-kawhaan', Concept: 'sixty', ID: 75241
#   - Word: 'pito ka-kawhaan', Concept: 'seventy', ID: 75242
#   - Word: 'walo ka-kawhaan', Concept: 'eighty', ID: 75243
#   - Word: 'siyam ka-kawhaan', Concept: 'ninety', ID: 75244
#   - Word: 'usa ka-gatos', Concept: 'one hundred', ID: 75245
#   - Word: 'usa ka-gatos ug kawhaan'g tulo', Concept: 'one hundred and twenty three', ID: 75246
#   - Word: 'duha ka-gatos', Concept: 'two hundred', ID: 75247
#   - Word: 'usa ka-gatos ka libo', Concept: 'one hundred thousand', ID: 75248
#   - Word: 'bag-o', Concept: 'new', ID: 75261
#   - Word: 'kagab-ihon', Concept: 'twilight, dawn', ID: 75281
#   - Word: 'tam-is', Concept: 'sweet', ID: 75308
#   - Word: 'tan-aw', Concept: 'see', ID: 75318
#   - Word: 'las-a', Concept: 'taste', ID: 75338
#   - Word: 'bug-at', Concept: 'heavy', ID: 75348
#   - Word: 'gan-ay', Concept: 'light (weight)', ID: 75349
#   - Word: 'nagtug-an', Concept: 'surprised', ID: 75363
#   - Word: 'bug-at', Concept: 'proud', ID: 75380
#   - Word: 'nag-isa', Concept: 'lonely', ID: 75404
#   - Word: 'kat-on', Concept: 'understand', ID: 75407
#   - Word: 'tum-aw', Concept: 'remember', ID: 75424
#   - Word: 'kanus-a', Concept: 'when?', ID: 75448
#   - Word: 'idul-ong', Concept: 'escort, bring s.o. somewhere', ID: 75498
#
# Language: Yakan, Symbol/Pattern: ''' (Column: 'Word')
#   - Word: 'pu'', Concept: 'island', ID: 75570
#   - Word: 'sahasa'', Concept: 'coral (rock)', ID: 75571
#   - Word: 'sahasa'', Concept: '(coral) reef', ID: 75572
#   - Word: 'bohe'', Concept: 'water', ID: 75575
#   - Word: 'tengnga' sellang', Concept: 'ocean', ID: 75577
#   - Word: 'suba'', Concept: 'river', ID: 75586
#   - Word: 'sapa'', Concept: 'stream', ID: 75587
#   - Word: 'bihing suba'', Concept: 'riverbank', ID: 75589
#   - Word: 'bohe' pansul', Concept: 'spring', ID: 75591
#   - Word: 'bohe' kupung', Concept: 'well', ID: 75592
#   - Word: 'diyata'', Concept: 'forest', ID: 75595
#   - Word: 'alu'', Concept: 'dew', ID: 75616
#   - Word: 'amma'', Concept: 'father', ID: 75655
#   - Word: 'ina'', Concept: 'mother', ID: 75656
#   - Word: 'apu' lilla', Concept: 'grandfather', ID: 75668
#   - Word: 'apu' dende', Concept: 'grandmother', ID: 75669
#   - Word: 'apa'', Concept: 'uncle', ID: 75672
#   - Word: 'apa'', Concept: 'mother's brother', ID: 75673
#   - Word: 'babu'', Concept: 'aunt', ID: 75674
#   - Word: 'danganakan min tidde'', Concept: 'cross-cousin', ID: 75678
#   - Word: 'apu'', Concept: 'ancestors', ID: 75680
#   - Word: 'abahi' lilla', Concept: 'father-in-law', ID: 75682
#   - Word: 'abahi' dende', Concept: 'mother-in-law', ID: 75683
#   - Word: 'anak ilu'', Concept: 'orphan', ID: 75688
#   - Word: 'sapi'', Concept: 'cow', ID: 75703
#   - Word: 'belle'', Concept: 'eagle', ID: 75715
#   - Word: 'belle'', Concept: 'hawk', ID: 75716
#   - Word: 'buri'', Concept: 'roe, fish eggs', ID: 75732
#   - Word: 'kuhita'', Concept: 'octopus', ID: 75733
#   - Word: 'tehe'-tehe'', Concept: 'sea urchin', ID: 75749
#   - Word: 'kuya'', Concept: 'monkey', ID: 75753
#   - Word: 'kulisa'', Concept: 'louse eggs', ID: 75756
#   - Word: 'sipit kala'', Concept: 'scorpion', ID: 75766
#   - Word: 'luma' lawa'', Concept: 'spider web, cobweb', ID: 75770
#   - Word: 'linta'', Concept: 'leech', ID: 75784
#   - Word: 'kaba'-kaba'', Concept: 'butterfly', ID: 75786
#   - Word: 'tekke'', Concept: 'gecko', ID: 75793
#   - Word: 'tai' lalat', Concept: 'mole, birthmark', ID: 75800
#   - Word: 'laha'', Concept: 'blood', ID: 75809
#   - Word: 'bayhu'', Concept: 'cheek', ID: 75823
#   - Word: 'tantu longa'', Concept: 'sty', ID: 75831
#   - Word: 'della'', Concept: 'tongue', ID: 75841
#   - Word: 'ngile'', Concept: 'gums', ID: 75844
#   - Word: 'buli' kellong', Concept: 'nape of one's neck', ID: 75849
#   - Word: 'tombo'', Concept: 'index finger', ID: 75864
#   - Word: 'tape'', Concept: 'foot', ID: 75869
#   - Word: 'pusu'', Concept: 'shin', ID: 75872
#   - Word: 'limpa' bittes', Concept: 'footprint', ID: 75877
#   - Word: 'pundu'', Concept: 'nipple, teat', ID: 75884
#   - Word: 'bulli'', Concept: 'buttocks', ID: 75895
#   - Word: 'lowang buli'', Concept: 'anus', ID: 75896
#   - Word: 'boto'', Concept: 'penis', ID: 75899
#   - Word: 'manni'', Concept: 'semen, sperm', ID: 75901
#   - Word: 'maghasu'', Concept: 'masturbate', ID: 75902
#   - Word: 'ngalura'', Concept: 'spit', ID: 75911
#   - Word: 'nguta'', Concept: 'vomit', ID: 75913
#   - Word: 'kinaru'', Concept: 'sleepy', ID: 75921
#   - Word: 'nange'', Concept: 'urine', ID: 75925
#   - Word: 'amange'', Concept: 'urinate', ID: 75926
#   - Word: 'sungi'', Concept: 'defecate', ID: 75927
#   - Word: 'magsungi'-sungi'', Concept: 'diarrhea', ID: 75928
#   - Word: 'tai'', Concept: 'excrement', ID: 75929
#   - Word: 'muntu'', Concept: 'swell', ID: 75950
#   - Word: 'limpa' bakat', Concept: 'scar', ID: 75953
#   - Word: 'samua'', Concept: 'pimple', ID: 75954
#   - Word: 'nana'', Concept: 'pus', ID: 75960
#   - Word: 'mata'', Concept: 'unripe', ID: 75975
#   - Word: 'pinalaga'', Concept: 'stew', ID: 75982
#   - Word: 'mapa'', Concept: 'chew', ID: 75990
#   - Word: 'mag--essoh'', Concept: 'swallow', ID: 75992
#   - Word: 'kaha'', Concept: 'frying pan', ID: 75996
#   - Word: 'mag-eddo' pongngot', Concept: 'shave', ID: 76006
#   - Word: 'loho'', Concept: 'soup, broth', ID: 76011
#   - Word: 'bawang pote'', Concept: 'garlic', ID: 76015
#   - Word: 'bua' kayu'', Concept: 'fruit', ID: 76017
#   - Word: 'badju'', Concept: 'clothing', ID: 76030
#   - Word: 'magtahi'', Concept: 'sew', ID: 76035
#   - Word: 'badju'', Concept: 'shirt', ID: 76038
#   - Word: 'luma'', Concept: 'house', ID: 76050
#   - Word: 'deo' luma'', Concept: 'space under a house', ID: 76053
#   - Word: 'kura'-kura'', Concept: 'rafter', ID: 76075
#   - Word: 'ngeddo' bohe'', Concept: 'fetch water', ID: 76078
#   - Word: 'magkali'', Concept: 'dig', ID: 76083
#   - Word: 'pinag dambuwa'', Concept: 'bunch', ID: 76106
#   - Word: 'upa'', Concept: 'chew betel', ID: 76115
#   - Word: 'pag-isian upa'', Concept: 'betel pouch', ID: 76116
#   - Word: 'pag-isian upa'', Concept: 'bag for betelnut', ID: 76117
#   - Word: 'tabaku'', Concept: 'tobacco', ID: 76118
#   - Word: 'getta'', Concept: 'sap', ID: 76120
#   - Word: 'getta'', Concept: 'resin', ID: 76121
#   - Word: 'paipa'', Concept: 'midrib of palm leaf', ID: 76127
#   - Word: 'pusu'', Concept: 'banana heart', ID: 76136
#   - Word: 'iba'', Concept: 'averrhoa blimbi', ID: 76141
#   - Word: 'nangka'', Concept: 'jackfruit', ID: 76146
#   - Word: 'kabasi'', Concept: 'pumpkin, squash', ID: 76155
#   - Word: 'leppi'', Concept: 'fold', ID: 76169
#   - Word: 'tawwa'', Concept: 'hit', ID: 76174
#   - Word: 'tinebba'', Concept: 'cut down', ID: 76179
#   - Word: 'mulekka'', Concept: 'crack', ID: 76190
#   - Word: 'magbahagi'', Concept: 'split', ID: 76191
#   - Word: 'ginesse'', Concept: 'tear, rip', ID: 76193
#   - Word: 'ngoso'', Concept: 'wash', ID: 76201
#   - Word: 'basi'', Concept: 'iron, of metal', ID: 76210
#   - Word: 'labo'', Concept: 'fall down', ID: 76220
#   - Word: 'hebba'', Concept: 'fall over', ID: 76221
#   - Word: 'labo'', Concept: 'drop', ID: 76222
#   - Word: 'nipa'', Concept: 'kick', ID: 76234
#   - Word: 'tahala'', Concept: 'flee, run away', ID: 76245
#   - Word: 'buli' kappal', Concept: 'stern', ID: 76266
#   - Word: 'munda' kappal', Concept: 'prow', ID: 76267
#   - Word: 'soha'', Concept: 'punt pole, boat pole', ID: 76270
#   - Word: 'saw'u', Concept: 'anchor', ID: 76273
#   - Word: 'kaeddo'', Concept: 'get, obtain, take', ID: 76279
#   - Word: 'masgsambi'', Concept: 'trade, barter', ID: 76293
#   - Word: 'tabu'', Concept: 'market', ID: 76294
#   - Word: 'halga'', Concept: 'price', ID: 76295
#   - Word: 'halga' teed', Concept: 'expensive', ID: 76296
#   - Word: 'lugi'', Concept: 'lose in business', ID: 76298
#   - Word: 'binahagi'', Concept: 'share, distribute', ID: 76299
#   - Word: 'mag-badju'', Concept: 'dress', ID: 76300
#   - Word: 'tiya'', Concept: 'at', ID: 76301
#   - Word: 'sitengnga'', Concept: 'between', ID: 76305
#   - Word: 'diyawa'', Concept: 'below', ID: 76307
#   - Word: 'diyata'', Concept: 'above', ID: 76308
#   - Word: 'suba'', Concept: 'upriver', ID: 76311
#   - Word: 'behe suba'', Concept: 'downstream', ID: 76312
#   - Word: 'ningko'', Concept: 'sit', ID: 76318
#   - Word: 'tahala'', Concept: 'leave behind, abandon', ID: 76324
#   - Word: 'sitengnga'', Concept: 'in the middle of', ID: 76338
#   - Word: 'taha'', Concept: 'small', ID: 76350
#   - Word: 'dambuwa'', Concept: 'one', ID: 76369
#   - Word: 'walu'', Concept: 'eight', ID: 76376
#   - Word: 'sampuk dambuwa'', Concept: 'eleven', ID: 76379
#   - Word: 'tellumpu'', Concept: 'thirty', ID: 76394
#   - Word: 'ampatpu'', Concept: 'forty', ID: 76395
#   - Word: 'limempu'', Concept: 'fifty', ID: 76396
#   - Word: 'ennempu'', Concept: 'sixty', ID: 76397
#   - Word: 'pitumpu'', Concept: 'seventy', ID: 76398
#   - Word: 'walumpu'', Concept: 'eighty', ID: 76399
#   - Word: 'siyampu'', Concept: 'ninety', ID: 76400
#   - Word: 'niya' dusab', Concept: 'some', ID: 76411
#   - Word: 'penno'', Concept: 'full', ID: 76413
#   - Word: 'ga nia'', Concept: 'empty', ID: 76414
#   - Word: 'tonga'', Concept: 'half', ID: 76415
#   - Word: 'tagna'', Concept: 'long time', ID: 76419
#   - Word: 'ninga' bahangi', Concept: 'midnight', ID: 76434
#   - Word: 'dai' ellew', Concept: 'twilight, dawn', ID: 76435
#   - Word: 'lettu' ellew', Concept: 'noon, midday', ID: 76437
#   - Word: 'paguwa' ne mata ellew', Concept: 'sunrise', ID: 76439
#   - Word: 'di buhi'', Concept: 'last night', ID: 76445
#   - Word: 'gana' lessane', Concept: 'bland', ID: 76464
#   - Word: 'pote'', Concept: 'white', ID: 76477
#   - Word: 'pinegga'', Concept: 'squeeze', ID: 76483
#   - Word: 'tuwa'', Concept: 'hard (not soft)', ID: 76488
#   - Word: 'tuwa'', Concept: 'freeze', ID: 76489
#   - Word: 'lanu'', Concept: 'smooth', ID: 76493
#   - Word: 'basse'', Concept: 'wet', ID: 76499
#   - Word: 'toho'', Concept: 'dry', ID: 76501
#   - Word: 'toho' ne', Concept: 'dry up', ID: 76502
#   - Word: 'lemmi'', Concept: 'dirty', ID: 76508
#   - Word: 'maase'', Concept: 'pity', ID: 76520
#   - Word: 'bohe' mata', Concept: 'tear', ID: 76522
#   - Word: 'gai' baya'', Concept: 'don't like, not want', ID: 76531
#   - Word: 'mene'', Concept: 'choose', ID: 76532
#   - Word: 'tawwa'', Concept: 'correct', ID: 76533
#   - Word: 'kamali'', Concept: 'wrong', ID: 76541
#   - Word: 'lemmi'', Concept: 'ugly', ID: 76544
#   - Word: 'tuyu'', Concept: 'hard-working', ID: 76547
#   - Word: 'ngadji'', Concept: 'learn', ID: 76562
#   - Word: 'magto'', Concept: 'teach', ID: 76564
#   - Word: 'dumain sai'', Concept: 'isn't that so?', ID: 76581
#   - Word: 'nia'', Concept: 'has x', ID: 76583
#   - Word: 'ga' nia'', Concept: 'there is not', ID: 76584
#   - Word: 'landu'', Concept: 'intensifier / very', ID: 76585
#   - Word: 'sali'', Concept: 'same', ID: 76595
#   - Word: 'nakura'', Concept: 'chieftain', ID: 76630
#   - Word: 'mag pasawe'', Concept: 'escort, bring s.o. somewhere', ID: 76640
#   - Word: 'gai ku baya'', Concept: 'oppose', ID: 76642
#   - Word: 'bono'', Concept: 'war, battle', ID: 76648
#   - Word: 'pana'', Concept: 'arrow', ID: 76654
#   - Word: 'sara'', Concept: 'judge', ID: 76671
#   - Word: 'tinuksa'', Concept: 'accuse', ID: 76672
#   - Word: 'multa'', Concept: 'penalty', ID: 76674
#   - Word: 'pari'', Concept: 'priest (protestant)', ID: 76688
#   - Word: 'pari'', Concept: 'priest (catholic)', ID: 76689
#   - Word: 'nukna'', Concept: 'curse', ID: 76693
#   - Word: 'palkata'an', Concept: 'sorcerer, witch', ID: 76694
#
# Language: Yakan, Symbol/Pattern: '-' (Column: 'Word')
#   - Word: 'benek-benek', Concept: 'drizzle', ID: 75624
#   - Word: 'dakanak-dakanak', Concept: 'child', ID: 75644
#   - Word: 'dakanak-dakanak', Concept: 'baby', ID: 75647
#   - Word: 'kaapu-apuan', Concept: 'great-grandparent', ID: 75681
#   - Word: 'manuk-manuk', Concept: 'bird', ID: 75713
#   - Word: 'tangan-tangan', Concept: 'starfish', ID: 75731
#   - Word: 'lomba-lomba', Concept: 'dolphin', ID: 75737
#   - Word: 'tehe'-tehe'', Concept: 'sea urchin', ID: 75749
#   - Word: 'tangang-ngang', Concept: 'spider', ID: 75769
#   - Word: 'kaba'-kaba'', Concept: 'butterfly', ID: 75786
#   - Word: 'kasa-kasa', Concept: 'cicada', ID: 75788
#   - Word: 'delo-delo', Concept: 'snail', ID: 75790
#   - Word: 'kule-kule', Concept: 'tortoise', ID: 75797
#   - Word: 'umbun-umbunan', Concept: 'fontanelle', ID: 75821
#   - Word: 'delang-delang', Concept: 'uvula', ID: 75839
#   - Word: 'king-king', Concept: 'little finger, pinky', ID: 75865
#   - Word: 'bunga-bunga', Concept: 'calf', ID: 75871
#   - Word: 'magsungi'-sungi'', Concept: 'diarrhea', ID: 75928
#   - Word: 'kinapu-kapu', Concept: 'mold, mildew', ID: 75977
#   - Word: 'bang-bang posak', Concept: 'crumbs', ID: 75979
#   - Word: 'kina-ugtu', Concept: 'hungry', ID: 75985
#   - Word: 'mag--essoh'', Concept: 'swallow', ID: 75992
#   - Word: 'mag-ayak', Concept: 'sieve, strainer', ID: 76004
#   - Word: 'mag-eddo' pongngot', Concept: 'shave', ID: 76006
#   - Word: 'mag-grayn', Concept: 'grind, mill', ID: 76007
#   - Word: 'mag-anyam', Concept: 'weave', ID: 76033
#   - Word: 'sing-sing', Concept: 'ring (for finger)', ID: 76041
#   - Word: 'paha-paha', Concept: 'rack (for storing food)', ID: 76052
#   - Word: 'ding-ding', Concept: 'wall', ID: 76058
#   - Word: 'kura'-kura'', Concept: 'rafter', ID: 76075
#   - Word: 'mag-ani', Concept: 'harvest', ID: 76089
#   - Word: 'pag-isian upa'', Concept: 'betel pouch', ID: 76116
#   - Word: 'pag-isian upa'', Concept: 'bag for betelnut', ID: 76117
#   - Word: 'mag-gantung', Concept: 'hang by rope, strangle', ID: 76198
#   - Word: 'mag-iskoba', Concept: 'sweep', ID: 76204
#   - Word: 'mag-labey', Concept: 'pass-by', ID: 76247
#   - Word: 'mag-badju'', Concept: 'dress', ID: 76300
#   - Word: 'kag-kag', Concept: 'skinny (human)', ID: 76358
#   - Word: 'gana-gana', Concept: 'later, in a while', ID: 76430
#   - Word: 'dupang-dupang', Concept: 'insane, mentally ill', ID: 76561
#   - Word: 'sine-sine', Concept: 'whose?', ID: 76594
#   - Word: 'ubey-ubey', Concept: 'nickname', ID: 76612
# File 'OCSEAN_Languages_with_Bad_Symbols.xlsx' exported successfully to 'Pipeline results' folder.

# %%
# Initialize a counter for symbols
symbol_counts = Counter()

# Iterate through each word in the 'Word' column
for word in od_cleaned_no_parenthesis['Word']:
    # Iterate through each character in the word
    for char in word:
        # Check if the character is in 'really_badsymbols' and is not a space
        if char in really_badsymbols and char != ' ':
            symbol_counts[char] += 1

# Convert the symbol counts to a DataFrame for easier plotting
# Filter out symbols that didn't appear at all if desired, though Counter naturally handles this
plot_data = pd.DataFrame(symbol_counts.items(), columns=['Symbol', 'Frequency'])

# Sort the data by frequency for better visualization (optional)
plot_data = plot_data.sort_values(by='Frequency', ascending=False)

# Create the bar plot
plt.figure(figsize=(20, 8)) # Adjust figure size for better readability

# Plot the bars
bars = plt.bar(plot_data['Symbol'], plot_data['Frequency'], color='steelblue')

# Add data labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 2), ha='center', va='bottom', fontsize=8)

# Set labels and title
plt.xlabel('Bad Symbols')
plt.ylabel('Frequency')
plt.title('Frequency of Bad Symbols in \'Word\' Column')
#plt.grid(axis='y', linestyle='--', alpha=0.7) # Add a grid for better readability

# Ensure x-axis labels are not overlapping (especially if many symbols)
plt.xticks(rotation=0, ha='right')

# Adjust layout to prevent labels from being cut off
plt.tight_layout()

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'bad_symbols_frequency.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

# Display the plot
plt.show()

# %%
# Initialize a counter for symbols
symbol_counts = Counter()

# Iterate through each word in the 'Word' column
for word in od_cleaned['Word']:
    # Iterate through each character in the word
    for char in word:
        # Check if the character is in 'except_symbols' and is not a space
        if char in except_symbols and char != ' ':
            symbol_counts[char] += 1

# Convert the symbol counts to a DataFrame for easier plotting
# Filter out symbols that didn't appear at all if desired, though Counter naturally handles this
plot_data = pd.DataFrame(symbol_counts.items(), columns=['Symbol', 'Frequency'])

# Sort the data by frequency for better visualization (optional)
plot_data = plot_data.sort_values(by='Frequency', ascending=False)

# Create the bar plot
plt.figure(figsize=(20, 8)) # Adjust figure size for better readability

# Plot the bars
bars = plt.bar(plot_data['Symbol'], plot_data['Frequency'], color='steelblue')

# Add data labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 2), ha='center', va='bottom', fontsize=8)

# Set labels and title
plt.xlabel('Accepted Symbols')
plt.ylabel('Frequency')
plt.title('Frequency of Accepted Symbols in \'Word\' Column')
#plt.grid(axis='y', linestyle='--', alpha=0.7) # Add a grid for better readability

# Ensure x-axis labels are not overlapping (especially if many symbols)
plt.xticks(rotation=0, ha='right')

# Adjust layout to prevent labels from being cut off
plt.tight_layout()

# Define the path to save the plot
plot_path = os.path.join(results_folder_name, 'accepted_symbols_frequency.png')

# Export the plot with 999 DPI
plt.savefig(plot_path, dpi=999)

# Display the plot
plt.show()

# %% [markdown]
# # Convert to IPA

# %%
def ipa2tokens_list(d):
    ## Takes a list of dataframe column
    ## Apply transformation to words that are present, and collapse that back to a string
    ret = [''.join(ipa2tokens(x)) for x in d]
    return ret

# %%
od_with_IPA = od_cleaned.copy()
od_with_IPA['IPA']=ipa2tokens_list(od_cleaned['Word'])
od_with_IPA['Language']=[re.sub(r"\s+", '_', x) for x in od_with_IPA['Language']]
#od_with_IPA['concept']=[re.sub(r"\s+", '_', x) for x in od_with_IPA['concept']]

# %%
od_with_IPA
# Out:
#                Concept        Word       Language         IPA
# ID
# 0                  sun       wariy  Abui_Bunggeta       wariy
# 1                 moon        ʔuya  Abui_Bunggeta        ʔuya
# 2                 star       furiy  Abui_Bunggeta       furiy
# 3                  sky      ʔadiiy  Abui_Bunggeta      ʔadiiy
# 4                earth        buku  Abui_Bunggeta        buku
# ...                ...         ...            ...         ...
# 76690             imam        imam          Yakan        imam
# 76691            bless     ridjiki          Yakan     ridjiki
# 76692           redeem      tawbat          Yakan      tawbat
# 76693            curse      nuknaʔ          Yakan      nuknaʔ
# 76694  sorcerer, witch  palkataʔan          Yakan  palkataʔan
#
# [76694 rows x 4 columns]

# %%
od_with_IPA['Language'].value_counts()
# Out:
# Language
# Kankana_ey      1732
# Bulus           1694
# Cuyunon         1414
# Bicolano        1370
# Ilognon         1315
#                 ...
# Mauta            229
# Sangil           200
# Bali_Aga         197
# Kupang_Malay     142
# Sabu_Seba        100
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# # Exporting this to csv file
# Since the 'Wordlist' function only accepts data that is manually imported again to the code, not a variable.

# %%
# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = 'OCSEAN_processed_joineddata.tsv'
output_file_path = os.path.join(results_folder_name, file_name)

try:
    od_with_IPA.to_csv(output_file_path, sep='\t', index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")
# Out:
# File 'OCSEAN_processed_joineddata.tsv' exported successfully to 'Pipeline results' folder.

# %% [markdown]
# # Semantic Field information
#
# We want to know which concepts are associated with which semanitic fields. To do that we need:
#
# a) A list of concepts that are in our final data, `used_concepts`, and
# b) A list of all semantic fields recorded in our data, `semantic_fields`.
#
# The first comes directly from our `od_with_IPA` final concepts list. The second we make by returning to the raw data read in as `collection`.

# %%
used_concepts=od_with_IPA['Concept'].drop_duplicates()
used_concepts_df = used_concepts.to_frame(name='English')

# %%
semantic_fields_list=[]
for name, df in collection.items():
    if {'English', 'Semantic_Field'}.issubset(df.columns):
        temp = df[['English', 'Semantic_Field']].copy()
#        temp['Source'] = name  # Optional: track origin
        semantic_fields_list.append(temp)
semantic_fields = pd.concat(semantic_fields_list, ignore_index=True)
semantic_fields = semantic_fields.drop_duplicates()

semantic_fields
# Out:
#                  English              Semantic_Field
# 0                  world          The physical world
# 1                  Earth          The physical world
# 3      land, earth, soil          The physical world
# 4       dust, fine earth          The physical world
# 5                    mud          The physical world
# ...                  ...                         ...
# 17075            shoofly  Agriculture and vegetation
# 17076            bayleaf  Agriculture and vegetation
# 17077          the creat  Agriculture and vegetation
# 17078        devil's gut  Agriculture and vegetation
# 27722          peanuts    Agriculture and vegetation
#
# [1434 rows x 2 columns]

# %%
used_semantic_fields = pd.merge(
    used_concepts_df,
    semantic_fields[['English', 'Semantic_Field']],
    on='English',
    how='left'  # keeps all used_concepts, fills missing Semantic_Field with NaN
)
used_semantic_fields
used_semantic_fields['Semantic_Field'] = used_semantic_fields['Semantic_Field'].replace({
    'Foːd and drink': 'Food and drink',
    'Clothing and groːming': 'Clothing and grooming'
})
used_semantic_fields.columns=['Concept','Semantic_Field']

# %%
used_semantic_fields.head()
# Out:
#   Concept      Semantic_Field
# 0     sun  The physical world
# 1    moon  The physical world
# 2    star  The physical world
# 3     sky  The physical world
# 4   earth                 NaN

# %% [markdown]
# The following is a summary of how many concepts are in each semantic field.

# %%
counts = used_semantic_fields['Semantic_Field'].value_counts(dropna=False)
print(counts)
# Out:
# Semantic_Field
# NaN                               782
# The body                          187
# Agriculture and vegetation        148
# Food and drink                    127
# Animals                           103
# The physical world                 92
# Basic actions and technology       81
# Spatial relations                  60
# Kinship                            59
# Motion                             57
# Sense perception                   54
# Quantity                           49
# Emotions and values                46
# Clothing and grooming              38
# Time                               35
# Cognition                          33
# The house                          28
# Speech and language                28
# Warfare and hunting                25
# Possession                         23
# Social and political relations     19
# Religion and belief                18
# Miscellaneous function words        9
# Law                                 8
# Name: count, dtype: int64

# %% [markdown]
# ### Save the semantic field data
#
# We are now ready to recreate the complete dataset with Semantic_Field added as an annotation.

# %%
od_with_semantic_field = pd.merge(
    od_with_IPA,
    used_semantic_fields[['Concept', 'Semantic_Field']],
    on='Concept',
    how='left'  # keeps all used_concepts, fills missing Semantic_Field with NaN
)
od_with_semantic_field
# Out:
#                Concept        Word       Language         IPA  \
# 0                  sun       wariy  Abui_Bunggeta       wariy
# 1                 moon        ʔuya  Abui_Bunggeta        ʔuya
# 2                 star       furiy  Abui_Bunggeta       furiy
# 3                  sky      ʔadiiy  Abui_Bunggeta      ʔadiiy
# 4                earth        buku  Abui_Bunggeta        buku
# ...                ...         ...            ...         ...
# 82832             imam        imam          Yakan        imam
# 82833            bless     ridjiki          Yakan     ridjiki
# 82834           redeem      tawbat          Yakan      tawbat
# 82835            curse      nuknaʔ          Yakan      nuknaʔ
# 82836  sorcerer, witch  palkataʔan          Yakan  palkataʔan
#
#             Semantic_Field
# 0       The physical world
# 1       The physical world
# 2       The physical world
# 3       The physical world
# 4                      NaN
# ...                    ...
# 82832  Religion and belief
# 82833  Religion and belief
# 82834  Religion and belief
# 82835  Religion and belief
# 82836  Religion and belief
#
# [82837 rows x 5 columns]

# %%
# Export the DataFrame to an Excel file in the results folder
# Construct the full path to the output file
file_name = 'OCSEAN_processed_joineddata_semantic.tsv'
output_file_path = os.path.join(results_folder_name, file_name)

try:
    od_with_semantic_field.to_csv(output_file_path, sep='\t', index=False) # index=False prevents writing DataFrame index to Excel
    print(f"File '{file_name}' exported successfully to '{results_folder_name}' folder.")
except Exception as e:
    print(f"An error occurred during export: {e}")
# Out:
# File 'OCSEAN_processed_joineddata_semantic.tsv' exported successfully to 'Pipeline results' folder.

# %%
semantic_fields_by_language = od_with_semantic_field.groupby(['Language', 'Semantic_Field']).size().reset_index(name='Count')
print(semantic_fields_by_language)
# Out:
#            Language                Semantic_Field  Count
# 0     Abui_Bunggeta    Agriculture and vegetation     76
# 1     Abui_Bunggeta                       Animals     47
# 2     Abui_Bunggeta  Basic actions and technology     39
# 3     Abui_Bunggeta         Clothing and grooming     34
# 4     Abui_Bunggeta                     Cognition     31
# ...             ...                           ...    ...
# 1679          Yakan                      The body    173
# 1680          Yakan                     The house     26
# 1681          Yakan            The physical world     87
# 1682          Yakan                          Time     34
# 1683          Yakan           Warfare and hunting     24
#
# [1684 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create pivot table (Language x Semantic_Field)
heatmap_data = od_with_semantic_field.groupby(['Language', 'Semantic_Field']) \
                                     .size() \
                                     .unstack(fill_value=0)

# Step 2: Sort rows (Languages) by total count
row_totals = heatmap_data.sum(axis=1)
heatmap_data = heatmap_data.loc[row_totals.sort_values(ascending=False).index]

# Step 3: Sort columns (Semantic Fields) by total count
col_totals = heatmap_data.sum(axis=0)
heatmap_data = heatmap_data[col_totals.sort_values(ascending=False).index]

# Step 4: Plot
plt.figure(figsize=(12, 15))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Count of Semantic Fields per Language')
plt.ylabel('Language')
plt.xlabel('Semantic Field')
plt.tight_layout()
plt.savefig(os.path.join(results_folder_name, "Languages_by_concept.png"), dpi=60, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Geographical plot
#
# This is a summary plot of the data, just to help understand the geo information we have added.

# %%
def create_geographic_map(initial_sheet_filename, save_map=True, map_filename='OCSEAN_languages_map.png', dpi=999):
    """Create geographic map of languages."""
    print("\n" + "=" * 50)
    print("STEP 12: Creating geographic visualization")
    print("=" * 50)
    
    # Construct the full path to the file
    full_path_to_initial_sheet = os.path.join(results_folder_name, initial_sheet_filename)

    try:
        # Load geographic data using the full path
        geo_data = pd.read_excel(full_path_to_initial_sheet)
        print(f"Loaded geographic data successfully from: {full_path_to_initial_sheet} for {len(geo_data)} entries")
        #print(geo_data.head()) # Print a sample of loaded data
    except FileNotFoundError:
        print(f"Warning: {full_path_to_initial_sheet} not found. Skipping geographic visualization.")
    except Exception as e:
        print(f"An error occurred during loading: {e}")

    # Filter for entries with coordinates
    languages_geo = geo_data[geo_data["latitude"].notnull()].copy()
    print(f"Found coordinates for {len(languages_geo)} languages")
    
    if len(languages_geo) == 0:
        print("No geographic coordinates found. Skipping map creation.")
        return None
    
    # Create GeoDataFrame
    languages_geo["geometry"] = languages_geo.apply(
        lambda row: Point(row["longitude"], row["latitude"]), axis=1
    )
    languages_gdf = gpd.GeoDataFrame(languages_geo, geometry="geometry", crs="EPSG:4326")
    
    # Prepare data for plotting
    languages_gdf["Latitude"] = languages_gdf["latitude"]
    languages_gdf["Longitude"] = languages_gdf["longitude"]
    languages_gdf["Language"] = languages_gdf.get("Language_BasedOnMasterSheet", 
                                                  languages_gdf.get("Language", "Unknown"))
    
    # Handle date line crossing (convert positive longitudes to negative for Pacific view)
    languages_gdf["Longitude_Pacific"] = [
        (x - 360 if x > 0 else x) for x in languages_gdf["Longitude"]
    ]
    
    # Create map
    fig = plt.figure(figsize=(16, 10))
    ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
    
    # Set extent for Pacific region
    ax.set_extent([70, 200, -30, 30], crs=ccrs.PlateCarree())
    
    # Add map features
    ax.add_feature(cfeature.LAND, facecolor='lightgray', alpha=0.7)
    ax.add_feature(cfeature.OCEAN, facecolor='lightblue', alpha=0.5)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5)
    ax.add_feature(cfeature.BORDERS, linestyle=':', alpha=0.5)
    
    # Plot language points
    for idx, row in languages_gdf.iterrows():
        ax.plot(row['Longitude'], row['Latitude'], 'o', 
               color='red', markersize=6, transform=ccrs.PlateCarree(), 
               markeredgecolor='darkred', markeredgewidth=1)
        ax.text(row['Longitude'] + 1, row['Latitude'] + 1, row['Language'], 
               fontsize=9, transform=ccrs.PlateCarree(), 
               bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.7))
    
    plt.title("Geographic Distribution of OCSEAN Languages", fontsize=16, pad=20)
    
    
    # Save map
    #if save_map:
    #    map_file = map_filename
    #    plt.savefig(map_file, dpi=dpi, bbox_inches='tight')
    #    print(f"Map saved to: {map_file}")

    if save_map:
        # Construct the full path for the output map file
        full_map_output_path = os.path.join(results_folder_name, map_filename)
        try:
            plt.savefig(full_map_output_path, dpi=dpi, bbox_inches='tight')
            print(f"Map saved to: {full_map_output_path}")
        except Exception as e:
            print(f"Error saving map: {e}")
        
        plt.show()    
        plt.close() # Close the map plot after saving if it was created using plt.figure()

    
    
    return languages_gdf

# %%
geo_map = create_geographic_map(initial_sheet_filename='OCSEAN_initial_englishsheet.xlsx', save_map=True)
# Out:
# ==================================================
# STEP 12: Creating geographic visualization
# ==================================================
# Loaded geographic data successfully from: Pipeline results/OCSEAN_initial_englishsheet.xlsx for 79 entries
# Found coordinates for 39 languages
# Map saved to: Pipeline results/OCSEAN_languages_map.png
